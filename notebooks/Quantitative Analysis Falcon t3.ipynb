# %% [markdown]
# ## Quantitative Analysis

# %% [markdown]
# i.e. here, I perform a quantitative analysis of the training output datasets: are the trained models able to work better (or worse) under certain circumstances?
# That is:
# - with a certain type of quantifier? (all, exists) (is a certain type of quantifier harder?)
# - with a certain number of keys? (generally -> or specifically: with a certain number of predicates? / constants?) (is more keys / predicates / constants harder?)
# - with a certain number of constants?
# - with a certain number of predicates?
# - with a certain size of the world model? (is a bigger world model harder?)
# - with a certain number of operators? (is more operators harder?)
# - with a certain type of operator? (negation, implication, and-operator) -> especially: is there negation in front of quantifiers or not? // using only no operators vs. unary vs. binary operators // (is a certain type of operator harder (none, unary, binary)? is negation in front of quantifiers harder?)
# - etc. (e.g. do the models tend to produce tautologies / contradictions?)
#
# (dazu sowohl Output Datensatz als auch Input Datensatz laden, über id Mappen!!)
# => dann noch: weitere Spalten miteinbeziehen: correctIncorrect vs. Gibberish.
#
# - for evaluation, we chose the datapoints: 80000:81000
# - manche der unten stehenden Evals machen gegeben der Task keinen Sinn!!
#     - Task 1: Input:  World Model + Keys + Satisfied => also: macht nur world model count, constants count, keys count, predicates count Sinn. Aber nicht: quantifier, operator count, operator type.
#     - Task 2: Input: Formula + Satisfied => also: umgekehrt wie task 1: es macht nur: operator count, operator type, quantifier Sinn, (predicates count). Aber nicht: world model count, constants count, keys count.
#     - Task 3: Input: Formula + Keys + World Model => also: macht alles Sinn.

# %%
import json
import collections
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = 'Falcon-7b-instruct_trained_on_t3_task3.json' #TODO: change 
output_dataset = pd.read_json('../results/training-eval/' + filename)
filename = 'base_pred_logic_data.json'
base_dataset = pd.read_json('../datasets/' + filename)

# %%
output_dataset
# Out:
#                                              Predictions   References
# 80000  unsatisfiedDefinition: F: Joyful. b: Calm. s: ...  unsatisfied  \
# 80001  satisfiedLogic:true\n\nDecision:satisfied\n\nQ...    satisfied
# 80002  unsatisfiedDefinition: All x.(F(x) & -G(x))\n\...  unsatisfied
# 80003  satisfied.q: F is not Arrogant.\n\nHere is the...    satisfied
# 80004  satisfiedElements:G:true.e:Jovial. o:true. b:t...    satisfied
# ...                                                  ...          ...
# 80995  unsatisfiedDefinition: G: Antagonistic. F: Hum...  unsatisfied
# 80996  unsatisfiedDefinition: G: Heroic. F: Afraid. r...  unsatisfied
# 80997  satisfied.\n\nHere are the keys:\n\nG: Earnest...    satisfied
# 80998  satisfiedElements:G: Alarmed. F: Thoughtful. l...  unsatisfied
# 80999  unsatisfiedDefinition: G: Afraid. F: Sad. q: J...    satisfied
#
#        Correct  Gibberish
# 80000     True      False
# 80001    False      False
# 80002     True      False
# 80003    False      False
# 80004    False      False
# ...        ...        ...
# 80995     True      False
# 80996     True      False
# 80997    False      False
# 80998     True      False
# 80999    False      False
#
# [1000 rows x 4 columns]

# %%
# subset:
base_dataset = base_dataset.iloc[80000:81000]
len(base_dataset)
# Out:
# 1000

# %%
base_dataset
# Out:
#                           Formula Predicates Variables Operators Quantifiers
# 80000      all x.-(F(x) -> -G(x))     [G, F]       [x]   [->, -]         all  \
# 80001     -all x.-(F(x) -> -G(x))     [G, F]       [x]   [->, -]         all
# 80002        all x.(F(x) & -G(x))     [G, F]       [x]    [&, -]         all
# 80003       -all x.(F(x) & -G(x))     [G, F]       [x]    [&, -]         all
# 80004     exists x.(F(x) & -G(x))     [G, F]       [x]    [&, -]      exists
# ...                           ...        ...       ...       ...         ...
# 80995   -exists x.(G(x) -> -F(x))     [G, F]       [x]    [>, -]      exists
# 80996      all x.-(G(x) -> -F(x))     [G, F]       [x]   [->, -]         all
# 80997     -all x.-(G(x) -> -F(x))     [G, F]       [x]   [->, -]         all
# 80998   exists x.-(G(x) -> -F(x))     [G, F]       [x]   [->, -]      exists
# 80999  -exists x.-(G(x) -> -F(x))     [G, F]       [x]   [->, -]      exists
#
#                                   P_mapping
# 80000          {'G': 'Joyful', 'F': 'Calm'}  \
# 80001       {'G': 'Bothered', 'F': 'Witty'}
# 80002  {'G': 'Bothered', 'F': 'Supportive'}
# 80003  {'G': 'Arrogant', 'F': 'Mysterious'}
# 80004      {'G': 'Jovial', 'F': 'Creative'}
# ...                                     ...
# 80995  {'G': 'Antagonistic', 'F': 'Humble'}
# 80996        {'G': 'Heroic', 'F': 'Afraid'}
# 80997      {'G': 'Earnest', 'F': 'Panicky'}
# 80998   {'G': 'Alarmed', 'F': 'Thoughtful'}
# 80999           {'G': 'Afraid', 'F': 'Sad'}
#
#                                                C_mapping
# 80000  {'b': 'Aubrielle', 's': 'Wynter', 'g': 'Giovan...  \
# 80001  {'l': 'Phoenix', 'i': 'Rudy', 'b': 'Kolten', '...
# 80002       {'f': 'Ivan', 'k': 'Hayley', 'l': 'Gustavo'}
# 80003                                      {'q': 'Nova'}
# 80004  {'e': 'Beckett', 'o': 'Lia', 'b': 'Stella', 'q...
# ...                                                  ...
# 80995  {'d': 'Dulce', 'k': 'Ezra', 'h': 'Mateo', 's':...
# 80996      {'r': 'Abigail', 'c': 'Lennon', 'n': 'Salma'}
# 80997                    {'j': 'Gatlin', 's': 'Avianna'}
# 80998  {'l': 'Edith', 'e': 'Trace', 'f': 'Emery', 'b'...
# 80999  {'f': 'Judith', 'k': 'Ellie', 'q': 'Barrett', ...
#
#                                                     Keys
# 80000  G: Joyful. F: Calm. b: Aubrielle. s: Wynter. g...  \
# 80001  G: Bothered. F: Witty. l: Phoenix. i: Rudy. b:...
# 80002  G: Bothered. F: Supportive. f: Ivan. k: Hayley...
# 80003               G: Arrogant. F: Mysterious. q: Nova.
# 80004  G: Jovial. F: Creative. e: Beckett. o: Lia. b:...
# ...                                                  ...
# 80995  G: Antagonistic. F: Humble. d: Dulce. k: Ezra....
# 80996  G: Heroic. F: Afraid. r: Abigail. c: Lennon. n...
# 80997     G: Earnest. F: Panicky. j: Gatlin. s: Avianna.
# 80998  G: Alarmed. F: Thoughtful. l: Edith. e: Trace....
# 80999  G: Afraid. F: Sad. f: Judith. k: Ellie. q: Bar...
#
#                                                    Names
# 80000  [Aubrielle, Wynter, Giovanna, Dalary, Paislee,...  \
# 80001     [Phoenix, Rudy, Kolten, Dalton, Adley, Carson]
# 80002                            [Ivan, Hayley, Gustavo]
# 80003                                             [Nova]
# 80004  [Beckett, Lia, Stella, Nancy, Calliope, Chase,...
# ...                                                  ...
# 80995  [Dulce, Ezra, Mateo, Bentley, Adrian, Poppy, J...
# 80996                           [Abigail, Lennon, Salma]
# 80997                                  [Gatlin, Avianna]
# 80998  [Edith, Trace, Emery, Harry, Anika, Taliyah, M...
# 80999                    [Judith, Ellie, Barrett, Roman]
#
#                    Adjectives
# 80000          [Joyful, Calm]  \
# 80001       [Bothered, Witty]
# 80002  [Bothered, Supportive]
# 80003  [Arrogant, Mysterious]
# 80004      [Jovial, Creative]
# ...                       ...
# 80995  [Antagonistic, Humble]
# 80996        [Heroic, Afraid]
# 80997      [Earnest, Panicky]
# 80998   [Alarmed, Thoughtful]
# 80999           [Afraid, Sad]
#
#                                              World Model
# 80000   Aubrielle is Joyful. Wynter is not Joyful. Gi...  \
# 80001   Phoenix is Bothered. Rudy is not Bothered. Ko...
# 80002   Ivan is Bothered. Hayley is Bothered. Gustavo...
# 80003              Nova is Arrogant. Nova is Mysterious.
# 80004   Beckett is not Jovial. Lia is Jovial. Stella ...
# ...                                                  ...
# 80995   Dulce is not Antagonistic. Ezra is not Antago...
# 80996   Abigail is Heroic. Lennon is Heroic. Salma is...
# 80997   Gatlin is not Earnest. Avianna is Earnest. Ga...
# 80998   Edith is not Alarmed. Trace is not Alarmed. E...
# 80999   Judith is Afraid. Ellie is not Afraid. Barret...
#
#                                                Valuation    Satisfied
# 80000  [[b, Aubrielle], [s, Wynter], [g, Giovanna], [...  unsatisfied
# 80001  [[l, Phoenix], [i, Rudy], [b, Kolten], [s, Dal...    satisfied
# 80002  [[f, Ivan], [k, Hayley], [l, Gustavo], [G, [f]...  unsatisfied
# 80003                    [[q, Nova], [G, [q]], [F, [q]]]    satisfied
# 80004  [[e, Beckett], [o, Lia], [b, Stella], [q, Nanc...    satisfied
# ...                                                  ...          ...
# 80995  [[d, Dulce], [k, Ezra], [h, Mateo], [s, Bentle...  unsatisfied
# 80996  [[r, Abigail], [c, Lennon], [n, Salma], [G, [r...  unsatisfied
# 80997    [[j, Gatlin], [s, Avianna], [G, [s]], [F, [j]]]    satisfied
# 80998  [[l, Edith], [e, Trace], [f, Emery], [b, Harry...  unsatisfied
# 80999  [[f, Judith], [k, Ellie], [q, Barrett], [p, Ro...    satisfied
#
# [1000 rows x 13 columns]

# %% [markdown]
# #### Descriptive Statistics

# %%
satCounts = base_dataset['Satisfied'].value_counts()
satCounts
# Out:
# Satisfied
# satisfied      505
# unsatisfied    495
# Name: count, dtype: int64

# %%
# First: show descriptive statistics of evaluation dataset:
# number of quantifiers: all, exists
quantifiersCounts = base_dataset['Quantifiers'].value_counts()
quantifiersCounts
# Out:
# Quantifiers
# exists    503
# all       497
# Name: count, dtype: int64

# %%
# distribution of predicates
predicatesCounts = base_dataset['Predicates'].value_counts() # then add the singular F and G to one line
predicatesCounts
# Out:
# Predicates
# [G, F]    457
# [G]       281
# [F]       262
# Name: count, dtype: int64

# %%
# distribution of constants 
oldConstants = base_dataset['Names']
constants = []
for con in oldConstants:
    constants.append(len(con))
constantsCounts = collections.Counter(constants) # the keys() is what is counted, and the values() is the count
constantsCounts
# Out:
# Counter({7: 124,
#          6: 114,
#          3: 107,
#          1: 52,
#          5: 105,
#          10: 112,
#          2: 71,
#          9: 109,
#          4: 106,
#          8: 100})

# %%
temp = pd.DataFrame(list(zip(constantsCounts.keys(), constantsCounts.values())), columns=['Number_of_constants','Count']).sort_values('Number_of_constants')
temp.plot(kind="bar", x = "Number_of_constants")
# Out:
# <Axes: xlabel='Number_of_constants'>

# %%
# distribution of keys
keys_list = base_dataset['Keys']
keysTemp = []
for keys in keys_list:
    keysTemp.append(keys.count(':'))
keysCounts = collections.Counter(keysTemp)
keysCounts
# Out:
# Counter({9: 112,
#          8: 122,
#          5: 99,
#          3: 63,
#          7: 107,
#          12: 50,
#          4: 88,
#          11: 119,
#          6: 114,
#          10: 95,
#          2: 31})

# %%
temp = pd.DataFrame(list(zip(keysCounts.keys(), keysCounts.values())), columns=['Number_of_keys','Count']).sort_values('Number_of_keys')
temp.plot(kind="bar", x = "Number_of_keys")
# Out:
# <Axes: xlabel='Number_of_keys'>

# %%
# distribution of world model size
worldModel_list = base_dataset['World Model']
wmTemp = []
for wm in worldModel_list:
    wmTemp.append(wm.count('.'))
worldModelCounts = collections.Counter(wmTemp)
worldModelCounts
# Out:
# Counter({14: 55,
#          12: 53,
#          6: 109,
#          2: 63,
#          10: 108,
#          20: 50,
#          4: 80,
#          18: 57,
#          8: 112,
#          16: 43,
#          7: 69,
#          1: 31,
#          9: 52,
#          5: 59,
#          3: 59})

# %%
temp = pd.DataFrame(list(zip(worldModelCounts.keys(), worldModelCounts.values())), columns=['Number_of_Sentences','Count']).sort_values('Number_of_Sentences')
temp.plot(kind="bar", x = "Number_of_Sentences")
# Out:
# <Axes: xlabel='Number_of_Sentences'>

# %%
# generally: count all negations, implications, and-operators individually for each formula (string-find-count).
# from this deduce another list: total number of operators => plot this count. (is more operators harder?)
numNegations = []
numImplications = []
numAnds = []

formula_list = base_dataset['Formula']
for formula in formula_list:
    numNegations.append(formula.count("-"))
    numImplications.append(formula.count(">"))
    numAnds.append(formula.count("&"))

numTotalOperators = [a + b + c for (a, b, c) in zip(numNegations,numImplications,numAnds)]

# %%
negationCounts = collections.Counter(numNegations)
negationCounts
# Out:
# Counter({3: 293, 4: 141, 1: 184, 2: 309, 0: 45, 5: 28})

# %%
temp = pd.DataFrame(list(zip(negationCounts.keys(), negationCounts.values())), columns=['Number_of_Negations','Count']).sort_values('Number_of_Negations')
temp.plot(kind="bar", x = "Number_of_Negations")
# Out:
# <Axes: xlabel='Number_of_Negations'>

# %%
implicationCounts = collections.Counter(numImplications)
implicationCounts
# Out:
# Counter({1: 468, 0: 532})

# %%
andCounts = collections.Counter(numAnds)
andCounts
# Out:
# Counter({0: 526, 1: 474})

# %%
totalOperatorCounts = collections.Counter(numTotalOperators)
totalOperatorCounts
# Out:
# Counter({4: 293, 5: 141, 2: 167, 3: 296, 1: 60, 6: 28, 0: 15})

# %%
temp = pd.DataFrame(list(zip(totalOperatorCounts.keys(), totalOperatorCounts.values())), columns=['Number_of_Operators','Count']).sort_values('Number_of_Operators')
temp.plot(kind="bar", x = "Number_of_Operators")
# Out:
# <Axes: xlabel='Number_of_Operators'>

# %%
# (is a certain type of operator harder (none, unary, binary, unary + binary)?
# none is in totalOperatorCounts 
# noOperators = [True if x == 0 else False for x in totalOperatorCounts]
# <- this is not really needed, see above.

# %%
# how many times there is negation in front of quantifiers vs. not (is negation in front of quantifiers harder?)
numNegationInFront = []
for formula in formula_list:
    if formula[0] == "-":
        numNegationInFront.append(True)
    else:
        numNegationInFront.append(False)
negationInFrontCounts = collections.Counter(numNegationInFront)
negationInFrontCounts
# Out:
# Counter({False: 506, True: 494})

# %%
# unary is negationCounts > 0 und implicationCounts == 0 und andCounts == 0.
# binary is negationCounts == 0 und implicationCounts > 0 oder andCounts > 0.
# unary + binary == 
unaryOperators = []
binaryOperators = []
unaryBinaryOperators = []
for nega, impl, andop in zip(numNegations, numImplications, numAnds):
    if nega > 0:
        binaryOperators.append(False)
        if impl == 0 and andop == 0:
            unaryOperators.append(True)
            unaryBinaryOperators.append(False)
        else:
            unaryOperators.append(False)
            unaryBinaryOperators.append(True)
    else:
        binaryOperators.append(True)
        unaryBinaryOperators.append(False)
        unaryOperators.append(False)

# %%
unaryOperatorsCounts = collections.Counter(unaryOperators)
unaryOperatorsCounts
# Out:
# Counter({False: 957, True: 43})

# %%
binaryOperatorsCounts = collections.Counter(binaryOperators)
binaryOperatorsCounts
# Out:
# Counter({False: 955, True: 45})

# %%
unaryBinaryOperatorsCounts = collections.Counter(unaryBinaryOperators)
unaryBinaryOperatorsCounts
# Out:
# Counter({True: 912, False: 88})

# %% [markdown]
# #### Dataset specific statistics

# %% [markdown]
# assume, we have two more columns in the output dataset: Correct (True / False), Gibberish (True / False).
#
# But for now, just create bar charts for IncorrectCorrect.

# %%
output_dataset.head()
# Out:
#                                              Predictions   References
# 80000  unsatisfiedDefinition: F: Joyful. b: Calm. s: ...  unsatisfied  \
# 80001  satisfiedLogic:true\n\nDecision:satisfied\n\nQ...    satisfied
# 80002  unsatisfiedDefinition: All x.(F(x) & -G(x))\n\...  unsatisfied
# 80003  satisfied.q: F is not Arrogant.\n\nHere is the...    satisfied
# 80004  satisfiedElements:G:true.e:Jovial. o:true. b:t...    satisfied
#
#        Correct  Gibberish
# 80000     True      False
# 80001    False      False
# 80002     True      False
# 80003    False      False
# 80004    False      False

# %%
s = pd.Series([i for i in range(80000, 81000, 1)])
base_dataset.set_index([s])
base_dataset.head()
# Out:
#                        Formula Predicates Variables Operators Quantifiers
# 80000   all x.-(F(x) -> -G(x))     [G, F]       [x]   [->, -]         all  \
# 80001  -all x.-(F(x) -> -G(x))     [G, F]       [x]   [->, -]         all
# 80002     all x.(F(x) & -G(x))     [G, F]       [x]    [&, -]         all
# 80003    -all x.(F(x) & -G(x))     [G, F]       [x]    [&, -]         all
# 80004  exists x.(F(x) & -G(x))     [G, F]       [x]    [&, -]      exists
#
#                                   P_mapping
# 80000          {'G': 'Joyful', 'F': 'Calm'}  \
# 80001       {'G': 'Bothered', 'F': 'Witty'}
# 80002  {'G': 'Bothered', 'F': 'Supportive'}
# 80003  {'G': 'Arrogant', 'F': 'Mysterious'}
# 80004      {'G': 'Jovial', 'F': 'Creative'}
#
#                                                C_mapping
# 80000  {'b': 'Aubrielle', 's': 'Wynter', 'g': 'Giovan...  \
# 80001  {'l': 'Phoenix', 'i': 'Rudy', 'b': 'Kolten', '...
# 80002       {'f': 'Ivan', 'k': 'Hayley', 'l': 'Gustavo'}
# 80003                                      {'q': 'Nova'}
# 80004  {'e': 'Beckett', 'o': 'Lia', 'b': 'Stella', 'q...
#
#                                                     Keys
# 80000  G: Joyful. F: Calm. b: Aubrielle. s: Wynter. g...  \
# 80001  G: Bothered. F: Witty. l: Phoenix. i: Rudy. b:...
# 80002  G: Bothered. F: Supportive. f: Ivan. k: Hayley...
# 80003               G: Arrogant. F: Mysterious. q: Nova.
# 80004  G: Jovial. F: Creative. e: Beckett. o: Lia. b:...
#
#                                                    Names
# 80000  [Aubrielle, Wynter, Giovanna, Dalary, Paislee,...  \
# 80001     [Phoenix, Rudy, Kolten, Dalton, Adley, Carson]
# 80002                            [Ivan, Hayley, Gustavo]
# 80003                                             [Nova]
# 80004  [Beckett, Lia, Stella, Nancy, Calliope, Chase,...
#
#                    Adjectives
# 80000          [Joyful, Calm]  \
# 80001       [Bothered, Witty]
# 80002  [Bothered, Supportive]
# 80003  [Arrogant, Mysterious]
# 80004      [Jovial, Creative]
#
#                                              World Model
# 80000   Aubrielle is Joyful. Wynter is not Joyful. Gi...  \
# 80001   Phoenix is Bothered. Rudy is not Bothered. Ko...
# 80002   Ivan is Bothered. Hayley is Bothered. Gustavo...
# 80003              Nova is Arrogant. Nova is Mysterious.
# 80004   Beckett is not Jovial. Lia is Jovial. Stella ...
#
#                                                Valuation    Satisfied
# 80000  [[b, Aubrielle], [s, Wynter], [g, Giovanna], [...  unsatisfied
# 80001  [[l, Phoenix], [i, Rudy], [b, Kolten], [s, Dal...    satisfied
# 80002  [[f, Ivan], [k, Hayley], [l, Gustavo], [G, [f]...  unsatisfied
# 80003                    [[q, Nova], [G, [q]], [F, [q]]]    satisfied
# 80004  [[e, Beckett], [o, Lia], [b, Stella], [q, Nanc...    satisfied

# %%
# - with a certain type of quantifier? (all, exists)
temp_df = pd.concat([output_dataset['Correct'], base_dataset['Quantifiers']], axis=1)
temp_df.head()
# Out:
#        Correct Quantifiers
# 80000     True         all
# 80001    False         all
# 80002     True         all
# 80003    False         all
# 80004    False      exists

# %%
quantifierCounts = temp_df.groupby(['Correct', 'Quantifiers']).size()
quantifierCounts
# Out:
# Correct  Quantifiers
# False    all            211
#          exists         228
# True     all            286
#          exists         275
# dtype: int64

# %%
keyCounts_df = pd.DataFrame()
keyCounts_df["keyCounts"] = pd.DataFrame(keysTemp)
keyCounts_df = keyCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
keyCounts_df["Correct"] = output_dataset['Correct']
keyCounts_df
# Out:
#        keyCounts  Correct
# 80000          9     True
# 80001          8    False
# 80002          5     True
# 80003          3    False
# 80004          9    False
# ...          ...      ...
# 80995         10     True
# 80996          5     True
# 80997          4    False
# 80998         11     True
# 80999          6    False
#
# [1000 rows x 2 columns]

# %%
keyCounts = keyCounts_df.groupby(['Correct', 'keyCounts']).size()
keyCounts
# Out:
# Correct  keyCounts
# False    2            16
#          3            30
#          4            43
#          5            47
#          6            51
#          7            42
#          8            54
#          9            42
#          10           40
#          11           50
#          12           24
# True     2            15
#          3            33
#          4            45
#          5            52
#          6            63
#          7            65
#          8            68
#          9            70
#          10           55
#          11           69
#          12           26
# dtype: int64

# %%
dfp = keyCounts_df.pivot_table(index='keyCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
# - with a certain number of constants?
constantsCounts_df = pd.DataFrame()
constantsCounts_df["constantCounts"] = pd.DataFrame(constants)
constantsCounts_df = constantsCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
constantsCounts_df["Correct"] = output_dataset['Correct']
constantsCounts_df
# Out:
#        constantCounts  Correct
# 80000               7     True
# 80001               6    False
# 80002               3     True
# 80003               1    False
# 80004               7    False
# ...               ...      ...
# 80995               8     True
# 80996               3     True
# 80997               2    False
# 80998               9     True
# 80999               4    False
#
# [1000 rows x 2 columns]

# %%
constantCounts = constantsCounts_df.groupby(['Correct', 'constantCounts']).size()
constantCounts
# Out:
# Correct  constantCounts
# False    1                 27
#          2                 34
#          3                 53
#          4                 48
#          5                 45
#          6                 45
#          7                 45
#          8                 47
#          9                 45
#          10                50
# True     1                 25
#          2                 37
#          3                 54
#          4                 58
#          5                 60
#          6                 69
#          7                 79
#          8                 53
#          9                 64
#          10                62
# dtype: int64

# %%
dfp = constantsCounts_df.pivot_table(index='constantCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
# - with a certain number of predicates?

# %%
oldpredicates = base_dataset['Predicates']
predicates = []
for pred in oldpredicates:
    predicates.append(len(pred))

predicatesCounts_df = pd.DataFrame()
predicatesCounts_df["predicatesCounts"] = pd.DataFrame(predicates)
predicatesCounts_df = predicatesCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
predicatesCounts_df["Correct"] = output_dataset['Correct']
predicatesCounts_df

predicatesCounts = predicatesCounts_df.groupby(['Correct', 'predicatesCounts']).size()
predicatesCounts
# Out:
# Correct  predicatesCounts
# False    1                   238
#          2                   201
# True     1                   305
#          2                   256
# dtype: int64

# %%
dfp = predicatesCounts_df.pivot_table(index='predicatesCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
201/(256+201)
# Out:
# 0.43982494529540483

# %%
238/(305+238)
# Out:
# 0.43830570902394106

# %% [markdown]
# FIRST LEARNING: MORE PREDICATES IS HARDER!!

# %%
# - with a certain size of the world model?
wmCounts_df = pd.DataFrame()
wmCounts_df["WorldModelCounts"] = pd.DataFrame(wmTemp)
wmCounts_df = wmCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
wmCounts_df["Correct"] = output_dataset['Correct']
wmCounts_df
# Out:
#        WorldModelCounts  Correct
# 80000                14     True
# 80001                12    False
# 80002                 6     True
# 80003                 2    False
# 80004                14    False
# ...                 ...      ...
# 80995                16     True
# 80996                 6     True
# 80997                 4    False
# 80998                18     True
# 80999                 8    False
#
# [1000 rows x 2 columns]

# %%
wmCounts = wmCounts_df.groupby(['Correct', 'WorldModelCounts']).size()
wmCounts
# Out:
# Correct  WorldModelCounts
# False    1                   16
#          2                   30
#          3                   28
#          4                   37
#          5                   25
#          6                   47
#          7                   31
#          8                   54
#          9                   21
#          10                  46
#          12                  23
#          14                  14
#          16                  19
#          18                  24
#          20                  24
# True     1                   15
#          2                   33
#          3                   31
#          4                   43
#          5                   34
#          6                   62
#          7                   38
#          8                   58
#          9                   31
#          10                  62
#          12                  30
#          14                  41
#          16                  24
#          18                  33
#          20                  26
# dtype: int64

# %%
dfp = wmCounts_df.pivot_table(index='WorldModelCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %% [markdown]
# World model size does not seem to make a difference! -> but plot a regression or something.

# %%
# - with a certain number of operators? 
operatorCounts_df = pd.DataFrame()
operatorCounts_df["operatorCounts"] = pd.DataFrame(numTotalOperators)
operatorCounts_df = operatorCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
operatorCounts_df["Correct"] = output_dataset['Correct']
operatorCounts_df
# Out:
#        operatorCounts  Correct
# 80000               4     True
# 80001               5    False
# 80002               2     True
# 80003               3    False
# 80004               2    False
# ...               ...      ...
# 80995               4     True
# 80996               4     True
# 80997               5    False
# 80998               4     True
# 80999               5    False
#
# [1000 rows x 2 columns]

# %%
operatorCounts = operatorCounts_df.groupby(['Correct', 'operatorCounts']).size()
operatorCounts
# Out:
# Correct  operatorCounts
# False    0                   7
#          1                  22
#          2                  79
#          3                 151
#          4                 109
#          5                  50
#          6                  21
# True     0                   8
#          1                  38
#          2                  88
#          3                 145
#          4                 184
#          5                  91
#          6                   7
# dtype: int64

# %%
dfp = operatorCounts_df.pivot_table(index='operatorCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
# - with a certain type of operator? (negation, implication, and-operator) 
# negation
negationCounts_df = pd.DataFrame()
negationCounts_df["negationCounts"] = pd.DataFrame(numNegations)
negationCounts_df = negationCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
negationCounts_df["Correct"] = output_dataset['Correct']
negationCounts_df
# Out:
#        negationCounts  Correct
# 80000               3     True
# 80001               4    False
# 80002               1     True
# 80003               2    False
# 80004               1    False
# ...               ...      ...
# 80995               3     True
# 80996               3     True
# 80997               4    False
# 80998               3     True
# 80999               4    False
#
# [1000 rows x 2 columns]

# %%
negationCounts = negationCounts_df.groupby(['Correct', 'negationCounts']).size()
negationCounts
# Out:
# Correct  negationCounts
# False    0                  17
#          1                  86
#          2                 156
#          3                 109
#          4                  50
#          5                  21
# True     0                  28
#          1                  98
#          2                 153
#          3                 184
#          4                  91
#          5                   7
# dtype: int64

# %%
dfp = negationCounts_df.pivot_table(index='negationCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
# implication
implicationCounts_df = pd.DataFrame()
implicationCounts_df["implicationCounts"] = pd.DataFrame(numImplications)
implicationCounts_df = implicationCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
implicationCounts_df["Correct"] = output_dataset['Correct']
implicationCounts_df
# Out:
#        implicationCounts  Correct
# 80000                  1     True
# 80001                  1    False
# 80002                  0     True
# 80003                  0    False
# 80004                  0    False
# ...                  ...      ...
# 80995                  1     True
# 80996                  1     True
# 80997                  1    False
# 80998                  1     True
# 80999                  1    False
#
# [1000 rows x 2 columns]

# %%
implicationCounts = implicationCounts_df.groupby(['Correct', 'implicationCounts']).size()
implicationCounts
# Out:
# Correct  implicationCounts
# False    0                    237
#          1                    202
# True     0                    295
#          1                    266
# dtype: int64

# %%
dfp = implicationCounts_df.pivot_table(index='implicationCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
# and-operator
andOpCounts_df = pd.DataFrame()
andOpCounts_df["andOpCounts"] = pd.DataFrame(numAnds)
andOpCounts_df = andOpCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
andOpCounts_df["Correct"] = output_dataset['Correct']
andOpCounts_df
# Out:
#        andOpCounts  Correct
# 80000            0     True
# 80001            0    False
# 80002            1     True
# 80003            1    False
# 80004            1    False
# ...            ...      ...
# 80995            0     True
# 80996            0     True
# 80997            0    False
# 80998            0     True
# 80999            0    False
#
# [1000 rows x 2 columns]

# %%
andOpCounts = andOpCounts_df.groupby(['Correct', 'andOpCounts']).size()
andOpCounts
# Out:
# Correct  andOpCounts
# False    0              226
#          1              213
# True     0              300
#          1              261
# dtype: int64

# %%
dfp = andOpCounts_df.pivot_table(index='andOpCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
def get_frequencies(output_dataset, count_list, column_name):
    temp_df = pd.DataFrame()
    temp_df[column_name] = pd.DataFrame(count_list)
    temp_df = temp_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
    temp_df["Correct"] = output_dataset['Correct']
    return temp_df.groupby(['Correct', column_name]).size()

# %%
# -> especially: is there negation in front of quantifiers or not? 
get_frequencies(output_dataset, numNegationInFront, "NegationInFront")
# Out:
# Correct  NegationInFront
# False    False              223
#          True               216
# True     False              283
#          True               278
# dtype: int64

# %%
#  using only no operators vs. unary vs. binary operators // 
get_frequencies(output_dataset, unaryOperators, "UnaryOperator")
# Out:
# Correct  UnaryOperator
# False    False            422
#          True              17
# True     False            535
#          True              26
# dtype: int64

# %%
get_frequencies(output_dataset, binaryOperators, "BinaryOperator")
# Out:
# Correct  BinaryOperator
# False    False             422
#          True               17
# True     False             533
#          True               28
# dtype: int64

# %%
get_frequencies(output_dataset, unaryBinaryOperators, "UnaryAndBinaryOperators")
# Out:
# Correct  UnaryAndBinaryOperators
# False    False                       34
#          True                       405
# True     False                       54
#          True                       507
# dtype: int64

# %% [markdown]
# We need to look here at the relative frequencies: it tends to be about 5% ratio or 10% ratio. So quite balanced. i.e. no set of operators leads to a worse outcome. => Qualitative analysis necessary!

# %% [markdown]
# ### Tautologies / Contradictions

# %%
import nltk
from nltk.inference.prover9 import BaseProverCommand, Prover, Prover9Command
from nltk.sem import Expression
from nltk.sem.logic import (
    AllExpression,
    AndExpression,
    EqualityExpression,
    ExistsExpression,
    Expression,
    IffExpression,
    ImpExpression,
    NegatedExpression,
    OrExpression,
)
from nltk import *
from nltk.sem.drt import DrtParser
from nltk.sem import logic

# %%
# a formula without assumptions is generally false (instead of undefined) for ResolutionProver.
# Tested the functions below so that tautologies are recognised, contradictions as well, but not other formulas (which are neither contradictions or tautologies).

# %%
def is_tautology(expression):
    # needs to be true, regardless of the input.
    # needs to be false when negated, regardless of the input.
    if ResolutionProver().prove(expression, [], verbose=True) and not ResolutionProver().prove(NegatedExpression(expression), [], verbose=True):
        return True
    else:
        return False

# %%
def is_contradiction(expression):
    # needs to be false, regardless of the input.
    # needs to be true when negated, regardless of the input.
    if not ResolutionProver().prove(expression, [], verbose=True) and ResolutionProver().prove(NegatedExpression(expression), [], verbose=True):
        return True
    else:
        return False

# %%
read_expr = Expression.fromstring

# %%
formula = read_expr(base_dataset["Formula"].iloc[59])
formula = NegatedExpression(formula) # negating a contradiction makes it a tautology.
formula
# Out:
# <NegatedExpression -all x.(G(x) & -G(x))>

# %%
res = ResolutionProver().prove(formula, [], verbose=True)
# Out:
# [1] {G(z2)}   A
# [2] {-G(z3)}  A
# [3] {}        (1, 2)

# %% [markdown]
# Descriptive Statistics regarding tautologies

# %%
numTautologies = []
numContradictions = []
for i in range(len(base_dataset)):
    formula = base_dataset['Formula'].iloc[i]
    numTautologies.append(is_tautology(read_expr(formula)))
    numContradictions.append(is_contradiction(read_expr(formula)))
# Out:
# [1] {-F(z5), -G(z5)}  A
#
# [1] {-F(z7), -G(z7)}  A
#
# [1] {F(z9)}   A
# [2] {G(z10)}  A
#
# [1] {F(z12)}  A
# [2] {G(z13)}  A
#
# [1] {F(z15)}  A
# [2] {G(z16)}  A
#
# [1] {-F(z18), -G(z18)}  A
#
# [1] {-F(z20), G(z20)}  A
#
# [1] {-F(z22), G(z22)}  A
#
# [1] {F(z24)}   A
# [2] {-G(z25)}  A
#
# [1] {F(z27)}   A
# [2] {-G(z28)}  A
#
# [1] {F(z30)}   A
# [2] {-G(z31)}  A
#
# [1] {-F(z33), G(z33)}  A
#
# [1] {-F(z35), G(z35)}  A
#
# [1] {-F(z37), G(z37)}  A
#
# [1] {F(z39)}   A
# [2] {-G(z40)}  A
#
# [1] {F(z42)}   A
# [2] {-G(z43)}  A
#
# [1] {F(z45)}   A
# [2] {-G(z46)}  A
#
# [1] {-F(z48), G(z48)}  A
#
# [1] {F(z50)}   A
# [2] {-G(z51)}  A
#
# [1] {F(z53)}   A
# [2] {-G(z54)}  A
#
# [1] {-F(z56), G(z56)}  A
#
# [1] {-F(z58), G(z58)}  A
#
# [1] {-F(z60), G(z60)}  A
#
# [1] {F(z62)}   A
# [2] {-G(z63)}  A
#
# [1] {F(z65)}   A
# [2] {-G(z66)}  A
#
# [1] {F(z68)}   A
# [2] {-G(z69)}  A
#
# [1] {-F(z71), G(z71)}  A
#
# [1] {-F(z73), G(z73)}  A
#
# [1] {-F(z75), G(z75)}  A
#
# [1] {F(z77)}   A
# [2] {-G(z78)}  A
#
# [1] {G(z80)}   A
# [2] {-F(z81)}  A
#
# [1] {G(z83)}   A
# [2] {-F(z84)}  A
#
# [1] {-G(z86), F(z86)}  A
#
# [1] {G(z88)}   A
# [2] {-F(z89)}  A
#
# [1] {G(z91)}   A
# [2] {-F(z92)}  A
#
# [1] {-G(z94), F(z94)}  A
#
# [1] {-G(z96), F(z96)}  A
#
# [1] {-G(z98), F(z98)}  A
#
# [1] {G(z100)}   A
# [2] {-F(z101)}  A
#
# [1] {-G(z103), F(z103)}  A
#
# [1] {-G(z105), F(z105)}  A
#
# [1] {G(z107)}   A
# [2] {-F(z108)}  A
#
# [1] {G(z110)}   A
# [2] {-F(z111)}  A
#
# [1] {G(z113)}   A
# [2] {-F(z114)}  A
#
# [1] {-G(z116), F(z116)}  A
#
# [1] {-G(z118), F(z118)}  A
#
# [1] {-G(z120), F(z120)}  A
#
# [1] {G(z122)}   A
# [2] {-F(z123)}  A
#
# [1] {G(z125)}   A
# [2] {-F(z126)}  A
#
# [1] {G(z128)}   A
# [2] {-F(z129)}  A
#
# [1] {-G(z131), F(z131)}  A
#
# [1] {-G(z133), -F(z133)}  A
#
# [1] {-G(z135), -F(z135)}  A
#
# [1] {G(z137)}  A
# [2] {F(z138)}  A
#
# [1] {G(z140)}  A
# [2] {F(z141)}  A
#
# [1] {G(z143)}  A
# [2] {F(z144)}  A
#
# [1] {-G(z146), -F(z146)}  A
#
# [1] {-G(z148), -F(z148)}  A
#
# [1] {-G(z150), -F(z150)}  A
#
# [1] {G(z152)}  A
# [2] {F(z153)}  A
#
# [1] {G(z155)}  A
# [2] {F(z156)}  A
#
# [1] {G(z158)}  A
# [2] {F(z159)}  A
#
# [1] {-G(z161), -F(z161)}  A
#
# [1] {G(z163)}   A
# [2] {-G(z164)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z166), G(z166)}  A Tautology
#
# [1] {G(z168)}   A
# [2] {-G(z169)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z171), G(z171)}  A Tautology
#
# [1] {-G(z173), G(z173)}  A Tautology
#
# [1] {G(z175)}   A
# [2] {-G(z176)}  A
# [3] {}          (1, 2)
#
# [1] {G(z178)}   A
# [2] {-G(z179)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z181), G(z181)}  A Tautology
#
# [1] {G(z183)}   A
# [2] {-G(z184)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z186), G(z186)}  A Tautology
#
# [1] {-G(z188), G(z188)}  A Tautology
#
# [1] {G(z190)}   A
# [2] {-G(z191)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z193), G(z193)}  A Tautology
#
# [1] {-G(z195), G(z195)}  A Tautology
#
# [1] {G(z197)}   A
# [2] {-G(z198)}  A
# [3] {}          (1, 2)
#
# [1] {G(z200)}   A
# [2] {-G(z201)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z203), G(z203)}  A Tautology
#
# [1] {G(z205)}   A
# [2] {-G(z206)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z208), G(z208)}  A Tautology
#
# [1] {-G(z210), G(z210)}  A Tautology
#
# [1] {G(z212)}   A
# [2] {-G(z213)}  A
# [3] {}          (1, 2)
#
# [1] {G(z215)}   A
# [2] {-G(z216)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z218), G(z218)}  A Tautology
#
# [1] {G(z220)}   A
# [2] {-G(z221)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z223), -G(z223)}  A
#
# [1] {-G(z225), -G(z225)}  A
#
# [1] {G(z227)}  A
# [2] {G(z228)}  A
#
# [1] {G(z230)}  A
# [2] {G(z231)}  A
#
# [1] {G(z233)}  A
# [2] {G(z234)}  A
#
# [1] {-G(z236), -G(z236)}  A
#
# [1] {-G(z238), -G(z238)}  A
#
# [1] {-G(z240), -G(z240)}  A
#
# [1] {G(z242)}  A
# [2] {G(z243)}  A
#
# [1] {G(z245)}  A
# [2] {G(z246)}  A
#
# [1] {G(z248)}  A
# [2] {G(z249)}  A
#
# [1] {-G(z251), -G(z251)}  A
#
# [1] {G(z253)}  A
# [2] {G(z254)}  A
#
# [1] {G(z256)}  A
# [2] {G(z257)}  A
#
# [1] {-G(z259), -G(z259)}  A
#
# [1] {-G(z261), -G(z261)}  A
#
# [1] {-G(z263), -G(z263)}  A
#
# [1] {G(z265)}  A
# [2] {G(z266)}  A
#
# [1] {G(z268)}  A
# [2] {G(z269)}  A
#
# [1] {G(z271)}  A
# [2] {G(z272)}  A
#
# [1] {-G(z274), -G(z274)}  A
#
# [1] {-G(z276), -G(z276)}  A
#
# [1] {-G(z278), -G(z278)}  A
#
# [1] {G(z280)}  A
# [2] {G(z281)}  A
#
# [1] {G(z283)}  A
# [2] {F(z284)}  A
#
# [1] {G(z286)}  A
# [2] {F(z287)}  A
#
# [1] {-G(z289), -F(z289)}  A
#
# [1] {-G(z291), -F(z291)}  A
#
# [1] {-G(z293), -F(z293)}  A
#
# [1] {G(z295)}  A
# [2] {F(z296)}  A
#
# [1] {G(z298)}  A
# [2] {F(z299)}  A
#
# [1] {G(z301)}  A
# [2] {F(z302)}  A
#
# [1] {-G(z304), -F(z304)}  A
#
# [1] {-G(z306), -F(z306)}  A
#
# [1] {-G(z308), -F(z308)}  A
#
# [1] {G(z310)}  A
# [2] {F(z311)}  A
#
# [1] {-G(z313), -F(z313)}  A
#
# [1] {-G(z315), -F(z315)}  A
#
# [1] {G(z317)}  A
# [2] {F(z318)}  A
#
# [1] {G(z320)}  A
# [2] {F(z321)}  A
#
# [1] {G(z323)}  A
# [2] {F(z324)}  A
#
# [1] {-G(z326), -F(z326)}  A
#
# [1] {-G(z328), -F(z328)}  A
#
# [1] {-G(z330), -F(z330)}  A
#
# [1] {G(z332)}  A
# [2] {F(z333)}  A
#
# [1] {-G(z335), F(z335)}  A
#
# [1] {-G(z337), F(z337)}  A
#
# [1] {G(z339)}   A
# [2] {-F(z340)}  A
#
# [1] {G(z342)}   A
# [2] {-F(z343)}  A
#
# [1] {G(z345)}   A
# [2] {-F(z346)}  A
#
# [1] {-G(z348), F(z348)}  A
#
# [1] {-G(z350), F(z350)}  A
#
# [1] {-G(z352), F(z352)}  A
#
# [1] {G(z354)}   A
# [2] {-F(z355)}  A
#
# [1] {G(z357)}   A
# [2] {-F(z358)}  A
#
# [1] {G(z360)}   A
# [2] {-F(z361)}  A
#
# [1] {-G(z363), F(z363)}  A
#
# [1] {G(z365)}   A
# [2] {-F(z366)}  A
#
# [1] {G(z368)}   A
# [2] {-F(z369)}  A
#
# [1] {-G(z371), F(z371)}  A
#
# [1] {-G(z373), F(z373)}  A
#
# [1] {-G(z375), F(z375)}  A
#
# [1] {G(z377)}   A
# [2] {-F(z378)}  A
#
# [1] {G(z380)}   A
# [2] {-F(z381)}  A
#
# [1] {G(z383)}   A
# [2] {-F(z384)}  A
#
# [1] {-G(z386), F(z386)}  A
#
# [1] {-G(z388), F(z388)}  A
#
# [1] {-G(z390), F(z390)}  A
#
# [1] {G(z392)}   A
# [2] {-F(z393)}  A
#
# [1] {G(z395)}  A
# [2] {G(z396)}  A
#
# [1] {G(z398)}  A
# [2] {G(z399)}  A
#
# [1] {-G(z401), -G(z401)}  A
#
# [1] {-G(z403), -G(z403)}  A
#
# [1] {-G(z405), -G(z405)}  A
#
# [1] {G(z407)}  A
# [2] {G(z408)}  A
#
# [1] {G(z410)}  A
# [2] {G(z411)}  A
#
# [1] {G(z413)}  A
# [2] {G(z414)}  A
#
# [1] {-G(z416), -G(z416)}  A
#
# [1] {-G(z418), -G(z418)}  A
#
# [1] {-G(z420), -G(z420)}  A
#
# [1] {G(z422)}  A
# [2] {G(z423)}  A
#
# [1] {-G(z425), -G(z425)}  A
#
# [1] {-G(z427), -G(z427)}  A
#
# [1] {G(z429)}  A
# [2] {G(z430)}  A
#
# [1] {G(z432)}  A
# [2] {G(z433)}  A
#
# [1] {G(z435)}  A
# [2] {G(z436)}  A
#
# [1] {-G(z438), -G(z438)}  A
#
# [1] {G(z440)}  A
# [2] {G(z441)}  A
#
# [1] {G(z443)}  A
# [2] {G(z444)}  A
#
# [1] {-G(z446), -G(z446)}  A
#
# [1] {-G(z448), G(z448)}  A Tautology
#
# [1] {-G(z450), G(z450)}  A Tautology
#
# [1] {G(z452)}   A
# [2] {-G(z453)}  A
# [3] {}          (1, 2)
#
# [1] {G(z455)}   A
# [2] {-G(z456)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z458), G(z458)}  A Tautology
#
# [1] {G(z460)}   A
# [2] {-G(z461)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z463), G(z463)}  A Tautology
#
# [1] {-G(z465), G(z465)}  A Tautology
#
# [1] {G(z467)}   A
# [2] {-G(z468)}  A
# [3] {}          (1, 2)
#
# [1] {G(z470)}   A
# [2] {-G(z471)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z473), G(z473)}  A Tautology
#
# [1] {G(z475)}   A
# [2] {-G(z476)}  A
# [3] {}          (1, 2)
#
# [1] {G(z478)}   A
# [2] {-G(z479)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z481), G(z481)}  A Tautology
#
# [1] {G(z483)}   A
# [2] {-G(z484)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z486), G(z486)}  A Tautology
#
# [1] {-G(z488), G(z488)}  A Tautology
#
# [1] {G(z490)}   A
# [2] {-G(z491)}  A
# [3] {}          (1, 2)
#
# [1] {G(z493)}   A
# [2] {-G(z494)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z496), G(z496)}  A Tautology
#
# [1] {G(z498)}   A
# [2] {-G(z499)}  A
# [3] {}          (1, 2)
#
# [1] {-F(z501)}  A
# [2] {-F(z502)}  A
#
# [1] {-F(z504)}  A
# [2] {-F(z505)}  A
#
# [1] {F(z507), F(z507)}  A
#
# [1] {F(z509), F(z509)}  A
#
# [1] {F(z511), F(z511)}  A
#
# [1] {-F(z513)}  A
# [2] {-F(z514)}  A
#
# [1] {-F(z516)}  A
# [2] {-F(z517)}  A
#
# [1] {-F(z519)}  A
# [2] {-F(z520)}  A
#
# [1] {F(z522), F(z522)}  A
#
# [1] {F(z524), F(z524)}  A
#
# [1] {F(z526), F(z526)}  A
#
# [1] {-F(z528)}  A
# [2] {-F(z529)}  A
#
# [1] {-F(z531)}  A
# [2] {-F(z532)}  A
#
# [1] {-F(z534)}  A
# [2] {-F(z535)}  A
#
# [1] {F(z537), F(z537)}  A
#
# [1] {F(z539), F(z539)}  A
#
# [1] {F(z541), F(z541)}  A
#
# [1] {-F(z543)}  A
# [2] {-F(z544)}  A
#
# [1] {-F(z546)}  A
# [2] {-F(z547)}  A
#
# [1] {-F(z549)}  A
# [2] {-F(z550)}  A
#
# [1] {F(z552), F(z552)}  A
#
# [1] {F(z554), -F(z554)}  A Tautology
#
# [1] {F(z556), -F(z556)}  A Tautology
#
# [1] {-F(z558)}  A
# [2] {F(z559)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z561)}  A
# [2] {F(z562)}   A
# [3] {}          (1, 2)
#
# [1] {F(z564), -F(z564)}  A Tautology
#
# [1] {-F(z566)}  A
# [2] {F(z567)}   A
# [3] {}          (1, 2)
#
# [1] {F(z569), -F(z569)}  A Tautology
#
# [1] {F(z571), -F(z571)}  A Tautology
#
# [1] {-F(z573)}  A
# [2] {F(z574)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z576)}  A
# [2] {F(z577)}   A
# [3] {}          (1, 2)
#
# [1] {F(z579), -F(z579)}  A Tautology
#
# [1] {-F(z581)}  A
# [2] {F(z582)}   A
# [3] {}          (1, 2)
#
# [1] {F(z584), -F(z584)}  A Tautology
#
# [1] {F(z586), -F(z586)}  A Tautology
#
# [1] {-F(z588)}  A
# [2] {F(z589)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z591)}  A
# [2] {F(z592)}   A
# [3] {}          (1, 2)
#
# [1] {F(z594), -F(z594)}  A Tautology
#
# [1] {-F(z596)}  A
# [2] {F(z597)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z599)}  A
# [2] {-G(z600)}  A
#
# [1] {-F(z602)}  A
# [2] {-G(z603)}  A
#
# [1] {F(z605), G(z605)}  A
#
# [1] {-F(z607)}  A
# [2] {-G(z608)}  A
#
# [1] {-F(z610)}  A
# [2] {-G(z611)}  A
#
# [1] {F(z613), G(z613)}  A
#
# [1] {F(z615), G(z615)}  A
#
# [1] {F(z617), G(z617)}  A
#
# [1] {-F(z619)}  A
# [2] {-G(z620)}  A
#
# [1] {-F(z622)}  A
# [2] {-G(z623)}  A
#
# [1] {-F(z625)}  A
# [2] {-G(z626)}  A
#
# [1] {F(z628), G(z628)}  A
#
# [1] {F(z630), G(z630)}  A
#
# [1] {F(z632), G(z632)}  A
#
# [1] {-F(z634)}  A
# [2] {-G(z635)}  A
#
# [1] {F(z637), -G(z637)}  A
#
# [1] {F(z639), -G(z639)}  A
#
# [1] {-F(z641)}  A
# [2] {G(z642)}   A
#
# [1] {-F(z644)}  A
# [2] {G(z645)}   A
#
# [1] {-F(z647)}  A
# [2] {G(z648)}   A
#
# [1] {F(z650), -G(z650)}  A
#
# [1] {-F(z652)}  A
# [2] {G(z653)}   A
#
# [1] {-F(z655)}  A
# [2] {G(z656)}   A
#
# [1] {F(z658), -G(z658)}  A
#
# [1] {F(z660), -G(z660)}  A
#
# [1] {F(z662), -G(z662)}  A
#
# [1] {-F(z664)}  A
# [2] {G(z665)}   A
#
# [1] {-F(z667)}  A
# [2] {G(z668)}   A
#
# [1] {-F(z670)}  A
# [2] {G(z671)}   A
#
# [1] {F(z673), -G(z673)}  A
#
# [1] {-F(z675)}  A
# [2] {F(z676)}   A
# [3] {}          (1, 2)
#
# [1] {F(z678), -F(z678)}  A Tautology
#
# [1] {-F(z680)}  A
# [2] {F(z681)}   A
# [3] {}          (1, 2)
#
# [1] {F(z683), -F(z683)}  A Tautology
#
# [1] {F(z685), -F(z685)}  A Tautology
#
# [1] {-F(z687)}  A
# [2] {F(z688)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z690)}  A
# [2] {F(z691)}   A
# [3] {}          (1, 2)
#
# [1] {F(z693), -F(z693)}  A Tautology
#
# [1] {-F(z695)}  A
# [2] {F(z696)}   A
# [3] {}          (1, 2)
#
# [1] {F(z698), -F(z698)}  A Tautology
#
# [1] {F(z700), -F(z700)}  A Tautology
#
# [1] {-F(z702)}  A
# [2] {F(z703)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z705)}  A
# [2] {F(z706)}   A
# [3] {}          (1, 2)
#
# [1] {F(z708), -F(z708)}  A Tautology
#
# [1] {-F(z710)}  A
# [2] {F(z711)}   A
# [3] {}          (1, 2)
#
# [1] {F(z713), -F(z713)}  A Tautology
#
# [1] {F(z715), -F(z715)}  A Tautology
#
# [1] {-F(z717)}  A
# [2] {F(z718)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z720)}  A
# [2] {F(z721)}   A
# [3] {}          (1, 2)
#
# [1] {F(z723), -F(z723)}  A Tautology
#
# [1] {-F(z725)}  A
# [2] {F(z726)}   A
# [3] {}          (1, 2)
#
# [1] {F(z728), F(z728)}  A
#
# [1] {F(z730), F(z730)}  A
#
# [1] {-F(z732)}  A
# [2] {-F(z733)}  A
#
# [1] {-F(z735)}  A
# [2] {-F(z736)}  A
#
# [1] {-F(z738)}  A
# [2] {-F(z739)}  A
#
# [1] {F(z741), F(z741)}  A
#
# [1] {-F(z743)}  A
# [2] {-F(z744)}  A
#
# [1] {-F(z746)}  A
# [2] {-F(z747)}  A
#
# [1] {F(z749), F(z749)}  A
#
# [1] {-F(z751)}  A
# [2] {-F(z752)}  A
#
# [1] {-F(z754)}  A
# [2] {-F(z755)}  A
#
# [1] {F(z757), F(z757)}  A
#
# [1] {F(z759), F(z759)}  A
#
# [1] {F(z761), F(z761)}  A
#
# [1] {-F(z763)}  A
# [2] {-F(z764)}  A
#
# [1] {-F(z766)}  A
# [2] {-F(z767)}  A
#
# [1] {-F(z769)}  A
# [2] {-F(z770)}  A
#
# [1] {F(z772), F(z772)}  A
#
# [1] {F(z774), F(z774)}  A
#
# [1] {F(z776), F(z776)}  A
#
# [1] {-F(z778)}  A
# [2] {-F(z779)}  A
#
# [1] {-F(z781)}  A
# [2] {G(z782)}   A
#
# [1] {-F(z784)}  A
# [2] {G(z785)}   A
#
# [1] {F(z787), -G(z787)}  A
#
# [1] {F(z789), -G(z789)}  A
#
# [1] {F(z791), -G(z791)}  A
#
# [1] {-F(z793)}  A
# [2] {G(z794)}   A
#
# [1] {-F(z796)}  A
# [2] {G(z797)}   A
#
# [1] {-F(z799)}  A
# [2] {G(z800)}   A
#
# [1] {F(z802), -G(z802)}  A
#
# [1] {F(z804), -G(z804)}  A
#
# [1] {F(z806), -G(z806)}  A
#
# [1] {-F(z808)}  A
# [2] {G(z809)}   A
#
# [1] {F(z811), -G(z811)}  A
#
# [1] {F(z813), -G(z813)}  A
#
# [1] {-F(z815)}  A
# [2] {G(z816)}   A
#
# [1] {-F(z818)}  A
# [2] {G(z819)}   A
#
# [1] {-F(z821)}  A
# [2] {G(z822)}   A
#
# [1] {F(z824), -G(z824)}  A
#
# [1] {F(z826), -G(z826)}  A
#
# [1] {F(z828), -G(z828)}  A
#
# [1] {-F(z830)}  A
# [2] {G(z831)}   A
#
# [1] {-F(z833)}  A
# [2] {G(z834)}   A
#
# [1] {-F(z836)}  A
# [2] {G(z837)}   A
#
# [1] {F(z839), -G(z839)}  A
#
# [1] {F(z841), G(z841)}  A
#
# [1] {F(z843), G(z843)}  A
#
# [1] {-F(z845)}  A
# [2] {-G(z846)}  A
#
# [1] {-F(z848)}  A
# [2] {-G(z849)}  A
#
# [1] {-F(z851)}  A
# [2] {-G(z852)}  A
#
# [1] {F(z854), G(z854)}  A
#
# [1] {F(z856), G(z856)}  A
#
# [1] {F(z858), G(z858)}  A
#
# [1] {-F(z860)}  A
# [2] {-G(z861)}  A
#
# [1] {-F(z863)}  A
# [2] {-G(z864)}  A
#
# [1] {-F(z866)}  A
# [2] {-G(z867)}  A
#
# [1] {F(z869), G(z869)}  A
#
# [1] {-F(z871)}  A
# [2] {-G(z872)}  A
#
# [1] {-F(z874)}  A
# [2] {-G(z875)}  A
#
# [1] {F(z877), G(z877)}  A
#
# [1] {F(z879), G(z879)}  A
#
# [1] {F(z881), G(z881)}  A
#
# [1] {-F(z883)}  A
# [2] {-G(z884)}  A
#
# [1] {-F(z886)}  A
# [2] {-G(z887)}  A
#
# [1] {-F(z889)}  A
# [2] {-G(z890)}  A
#
# [1] {F(z892), G(z892)}  A
#
# [1] {-G(z894)}  A
# [2] {-F(z895)}  A
#
# [1] {-G(z897)}  A
# [2] {-F(z898)}  A
#
# [1] {G(z900), F(z900)}  A
#
# [1] {G(z902), F(z902)}  A
#
# [1] {G(z904), F(z904)}  A
#
# [1] {-G(z906)}  A
# [2] {-F(z907)}  A
#
# [1] {-G(z909)}  A
# [2] {-F(z910)}  A
#
# [1] {-G(z912)}  A
# [2] {-F(z913)}  A
#
# [1] {G(z915), F(z915)}  A
#
# [1] {G(z917), F(z917)}  A
#
# [1] {G(z919), F(z919)}  A
#
# [1] {-G(z921)}  A
# [2] {-F(z922)}  A
#
# [1] {-G(z924)}  A
# [2] {-F(z925)}  A
#
# [1] {-G(z927)}  A
# [2] {-F(z928)}  A
#
# [1] {G(z930), F(z930)}  A
#
# [1] {G(z932), F(z932)}  A
#
# [1] {G(z934), F(z934)}  A
#
# [1] {-G(z936)}  A
# [2] {-F(z937)}  A
#
# [1] {-G(z939)}  A
# [2] {-F(z940)}  A
#
# [1] {-G(z942)}  A
# [2] {-F(z943)}  A
#
# [1] {G(z945), F(z945)}  A
#
# [1] {G(z947), -F(z947)}  A
#
# [1] {G(z949), -F(z949)}  A
#
# [1] {-G(z951)}  A
# [2] {F(z952)}   A
#
# [1] {-G(z954)}  A
# [2] {F(z955)}   A
#
# [1] {-G(z957)}  A
# [2] {F(z958)}   A
#
# [1] {G(z960), -F(z960)}  A
#
# [1] {G(z962), -F(z962)}  A
#
# [1] {G(z964), -F(z964)}  A
#
# [1] {-G(z966)}  A
# [2] {F(z967)}   A
#
# [1] {-G(z969)}  A
# [2] {F(z970)}   A
#
# [1] {-G(z972)}  A
# [2] {F(z973)}   A
#
# [1] {G(z975), -F(z975)}  A
#
# [1] {-G(z977)}  A
# [2] {F(z978)}   A
#
# [1] {-G(z980)}  A
# [2] {F(z981)}   A
#
# [1] {G(z983), -F(z983)}  A
#
# [1] {G(z985), -F(z985)}  A
#
# [1] {G(z987), -F(z987)}  A
#
# [1] {-G(z989)}  A
# [2] {F(z990)}   A
#
# [1] {-G(z992)}  A
# [2] {F(z993)}   A
#
# [1] {-G(z995)}  A
# [2] {F(z996)}   A
#
# [1] {G(z998), -F(z998)}  A
#
# [1] {G(z1000), -F(z1000)}  A
#
# [1] {G(z1002), -F(z1002)}  A
#
# [1] {-G(z1004)}  A
# [2] {F(z1005)}   A
#
# [1] {-G(z1007)}  A
# [2] {-G(z1008)}  A
#
# [1] {-G(z1010)}  A
# [2] {-G(z1011)}  A
#
# [1] {G(z1013), G(z1013)}  A
#
# [1] {G(z1015), G(z1015)}  A
#
# [1] {G(z1017), G(z1017)}  A
#
# [1] {-G(z1019)}  A
# [2] {-G(z1020)}  A
#
# [1] {-G(z1022)}  A
# [2] {-G(z1023)}  A
#
# [1] {-G(z1025)}  A
# [2] {-G(z1026)}  A
#
# [1] {G(z1028), G(z1028)}  A
#
# [1] {G(z1030), G(z1030)}  A
#
# [1] {G(z1032), G(z1032)}  A
#
# [1] {-G(z1034)}  A
# [2] {-G(z1035)}  A
#
# [1] {G(z1037), G(z1037)}  A
#
# [1] {G(z1039), G(z1039)}  A
#
# [1] {-G(z1041)}  A
# [2] {-G(z1042)}  A
#
# [1] {G(z1044), G(z1044)}  A
#
# [1] {G(z1046), G(z1046)}  A
#
# [1] {-G(z1048)}  A
# [2] {-G(z1049)}  A
#
# [1] {G(z1051), -G(z1051)}  A Tautology
#
# [1] {G(z1053), -G(z1053)}  A Tautology
#
# [1] {-G(z1055)}  A
# [2] {G(z1056)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z1058)}  A
# [2] {G(z1059)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1061), -G(z1061)}  A Tautology
#
# [1] {-G(z1063)}  A
# [2] {G(z1064)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1066), -G(z1066)}  A Tautology
#
# [1] {G(z1068), -G(z1068)}  A Tautology
#
# [1] {-G(z1070)}  A
# [2] {G(z1071)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z1073)}  A
# [2] {G(z1074)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1076), -G(z1076)}  A Tautology
#
# [1] {-G(z1078)}  A
# [2] {G(z1079)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z1081)}  A
# [2] {G(z1082)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1084), -G(z1084)}  A Tautology
#
# [1] {-G(z1086)}  A
# [2] {G(z1087)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1089), -G(z1089)}  A Tautology
#
# [1] {G(z1091), -G(z1091)}  A Tautology
#
# [1] {-G(z1093)}  A
# [2] {G(z1094)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z1096)}  A
# [2] {G(z1097)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1099), -G(z1099)}  A Tautology
#
# [1] {-G(z1101)}  A
# [2] {G(z1102)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1104), -G(z1104)}  A Tautology
#
# [1] {G(z1106), -G(z1106)}  A Tautology
#
# [1] {-G(z1108)}  A
# [2] {G(z1109)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z1111)}  A
# [2] {F(z1112)}   A
#
# [1] {-G(z1114)}  A
# [2] {F(z1115)}   A
#
# [1] {G(z1117), -F(z1117)}  A
#
# [1] {-G(z1119)}  A
# [2] {F(z1120)}   A
#
# [1] {-G(z1122)}  A
# [2] {F(z1123)}   A
#
# [1] {G(z1125), -F(z1125)}  A
#
# [1] {G(z1127), -F(z1127)}  A
#
}   A
# [3] {}           (1, 2)
#
# [1] {G(z1254), -G(z1254)}  A Tautology
#
# [1] {G(z1256), -G(z1256)}  A Tautology
#
# [1] {-G(z1258)}  A
# [2] {G(z1259)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1261), G(z1261)}  A
#
# [1] {G(z1263), G(z1263)}  A
#
# [1] {-G(z1265)}  A
# [2] {-G(z1266)}  A
#
# [1] {-G(z1268)}  A
# [2] {-G(z1269)}  A
#
# [1] {-G(z1271)}  A
# [2] {-G(z1272)}  A
#
# [1] {G(z1274), G(z1274)}  A
#
# [1] {G(z1276), G(z1276)}  A
#
# [1] {G(z1278), G(z1278)}  A
#
# [1] {-G(z1280)}  A
# [2] {-G(z1281)}  A
#
# [1] {-G(z1283)}  A
# [2] {-G(z1284)}  A
#
# [1] {-G(z1286)}  A
# [2] {-G(z1287)}  A
#
# [1] {G(z1289), G(z1289)}  A
#
# [1] {-G(z1291)}  A
# [2] {-G(z1292)}  A
#
# [1] {-G(z1294)}  A
# [2] {-G(z1295)}  A
#
# [1] {G(z1297), G(z1297)}  A
#
# [1] {G(z1299), G(z1299)}  A
#
# [1] {G(z1301), G(z1301)}  A
#
# [1] {-G(z1303)}  A
# [2] {-G(z1304)}  A
#
# [1] {-G(z1306)}  A
# [2] {-G(z1307)}  A
#
# [1] {-G(z1309)}  A
# [2] {-G(z1310)}  A
#
# [1] {G(z1312), G(z1312)}  A
#
# [1] {G(z1314), G(z1314)}  A
#
# [1] {G(z1316), G(z1316)}  A
#
# [1] {-G(z1318)}  A
# [2] {-G(z1319)}  A
#
# [1] {-F(z1321)}  A
#
# [1] {-F(z1323)}  A
#
# [1] {F(z1325)}  A
#
# [1] {F(z1327)}  A
#
# [1] {F(z1329)}  A
#
# [1] {-F(z1331)}  A
#
# [1] {-F(z1333)}  A
#
# [1] {-F(z1335)}  A
#
# [1] {F(z1337)}  A
#
# [1] {F(z1339)}  A
#
# [1] {F(z1341)}  A
#
# [1] {-F(z1343)}  A
#
# [1] {-G(z1345)}  A
#
# [1] {-G(z1347)}  A
#
# [1] {G(z1349)}  A
#
# [1] {G(z1351)}  A
#
# [1] {G(z1353)}  A
#
# [1] {-G(z1355)}  A
#
# [1] {-G(z1357)}  A
#
# [1] {-G(z1359)}  A
#
# [1] {G(z1361)}  A
#
# [1] {G(z1363)}  A
#
# [1] {G(z1365)}  A
#
# [1] {-G(z1367)}  A
#
# [1] {F(z1369)}  A
#
# [1] {F(z1371)}  A
#
# [1] {-F(z1373)}  A
#
# [1] {-F(z1375)}  A
#
# [1] {-F(z1377)}  A
#
# [1] {F(z1379)}  A
#
# [1] {F(z1381)}  A
#
# [1] {F(z1383)}  A
#
# [1] {-F(z1385)}  A
#
# [1] {-F(z1387)}  A
#
# [1] {-F(z1389)}  A
#
# [1] {F(z1391)}  A
#
# [1] {G(z1393)}  A
#
# [1] {G(z1395)}  A
#
# [1] {-G(z1397)}  A
#
# [1] {-G(z1399)}  A
#
# [1] {-G(z1401)}  A
#
# [1] {G(z1403)}  A
#
# [1] {G(z1405)}  A
#
# [1] {G(z1407)}  A
#
# [1] {-G(z1409)}  A
#
# [1] {-G(z1411)}  A
#
# [1] {-G(z1413)}  A
#
# [1] {G(z1415)}  A
#
# [1] {F(z1417)}   A
# [2] {-F(z1418)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1420), F(z1420)}  A Tautology
#
# [1] {F(z1422)}   A
# [2] {-F(z1423)}  A
# [3] {}           (1, 2)
#
# [1] {F(z1425)}   A
# [2] {-F(z1426)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z
#
# [1] {-F(z1567), G(z1567)}  A
#
# [1] {-F(z1569), G(z1569)}  A
#
# [1] {F(z1571)}   A
# [2] {-G(z1572)}  A
#
# [1] {F(z1574)}   A
# [2] {-G(z1575)}  A
#
# [1] {F(z1577)}   A
# [2] {-G(z1578)}  A
#
# [1] {-F(z1580), G(z1580)}  A
#
# [1] {-F(z1582), -G(z1582)}  A
#
# [1] {-F(z1584), -G(z1584)}  A
#
# [1] {F(z1586)}  A
# [2] {G(z1587)}  A
#
# [1] {F(z1589)}  A
# [2] {G(z1590)}  A
#
# [1] {F(z1592)}  A
# [2] {G(z1593)}  A
#
# [1] {-F(z1595), -G(z1595)}  A
#
# [1] {-F(z1597), -G(z1597)}  A
#
# [1] {-F(z1599), -G(z1599)}  A
#
# [1] {F(z1601)}  A
# [2] {G(z1602)}  A
#
# [1] {F(z1604)}  A
# [2] {G(z1605)}  A
#
# [1] {F(z1607)}  A
# [2] {G(z1608)}  A
#
# [1] {-F(z1610), -G(z1610)}  A
#
# [1] {F(z1612)}  A
# [2] {G(z1613)}  A
#
# [1] {F(z1615)}  A
# [2] {G(z1616)}  A
#
# [1] {-F(z1618), -G(z1618)}  A
#
# [1] {-F(z1620), -G(z1620)}  A
#
# [1] {-F(z1622), -G(z1622)}  A
#
# [1] {F(z1624)}  A
# [2] {G(z1625)}  A
#
# [1] {F(z1627)}  A
# [2] {G(z1628)}  A
#
# [1] {F(z1630)}  A
# [2] {G(z1631)}  A
#
# [1] {-F(z1633), -G(z1633)}  A
#
# [1] {-F(z1635), -G(z1635)}  A
#
# [1] {-F(z1637), -G(z1637)}  A
#
# [1] {F(z1639)}  A
# [2] {G(z1640)}  A
#
# [1] {F(z1642)}  A
# [2] {F(z1643)}  A
#
# [1] {F(z1645)}  A
# [2] {F(z1646)}  A
#
# [1] {-F(z1648), -F(z1648)}  A
#
# [1] {-F(z1650), -F(z1650)}  A
#
# [1] {-F(z1652), -F(z1652)}  A
#
# [1] {F(z1654)}  A
# [2] {F(z1655)}  A
#
# [1] {-F(z1657), -F(z1657)}  A
#
# [1] {-F(z1659), -F(z1659)}  A
#
# [1] {F(z1661)}  A
# [2] {F(z1662)}  A
#
# [1] {-F(z1664), -F(z1664)}  A
#
# [1] {-F(z1666), -F(z1666)}  A
#
# [1] {F(z1668)}  A
# [2] {F(z1669)}  A
#
# [1] {F(z1671)}  A
# [2] {F(z1672)}  A
#
# [1] {F(z1674)}  A
# [2] {F(z1675)}  A
#
# [1] {-F(z1677), -F(z1677)}  A
#
# [1] {-F(z1679), -F(z1679)}  A
#
# [1] {-F(z1681), -F(z1681)}  A
#
# [1] {F(z1683)}  A
# [2] {F(z1684)}  A
#
# [1] {F(z1686)}  A
# [2] {F(z1687)}  A
#
# [1] {F(z1689)}  A
# [2] {F(z1690)}  A
#
# [1] {-F(z1692), -F(z1692)}  A
#
# [1] {-F(z1694), F(z1694)}  A Tautology
#
# [1] {-F(z1696), F(z1696)}  A Tautology
#
# [1] {F(z1698)}   A
# [2] {-F(z1699)}  A
# [3] {}           (1, 2)
#
# [1] {F(z1701)}   A
# [2] {-F(z1702)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1704), F(z1704)}  A Tautology
#
# [1] {F(z1706)}   A
# [2] {-F(z1707)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1709), F(z1709)}  A Tautology
#
# [1] {-F(z1711), F(z1711)}  A Tautology
#
# [1] {F(z1713)}   A
# [2] {-F(z1714)}  A
# [3] {}           (1, 2)
#
# [1] {F(z1716)}   A
# [2] {-F(z1717)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1719), F(z1719)}  A Tautology
#
# [1] {F(z1721)}   A
# [2] {-F(z1722)}  A
# [3] {}           (1, 2)
#
# [1] {F(z1724)}   A
# [2] {-F(z1725)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1727), F(z1727)}  A Tautology
#
# [1] {F(z1729)}   A
# [2] {-F(z1730)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1732), F(z1732)}  A Tautology
#
# [1] {-F(z1734), F(z1734)}  A Tautology
#
# [1] {F(z1736)}   A
# [2] {-F(z1737)}  A
# [3] {}           (1, 2)
#
# [1] {F(z1739)}   A
# [2] {-F(z1740)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1742), F(z1742)}  A Tautology
#
# [1] {F(z1744)}   A
# [2] {-F(z1745)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1747), F(z1747)}  A Tautology
#
# [1] {-F(z1749), F(z1749)}  A Tautology
#
# [1] {F(z1751)}   A
# [2] {-F(z1752)}  A
# [3] {}           (1, 2)
#
# [1] {F(z1754)}  A
# [2] {G(z1755)}  A
#
# [1] {F(z1757)}  A
# [2] {G(z1758)}  A
#
# [1] {-F(z1760), -G(z1760)}  A
#
# [1] {-F(z1762), -G(z1762)}  A
#
# [1] {-F(z1764), -G(z1764)}  A
#
# [1] {F(z1766)}  A
# [2] {G(z1767)}  A
#
# [1] {-F(z1769), -G(z1769)}  A
#
# [1] {-F(z1771), -G(z1771)}  A
#
# [1] {F(z1773)}  A
# [2] {G(z1774)}  A
#
# [1] {F(z1776)}  A
# [2] {G(z1777)}  A
#
# [1] {F(z1779)}  A
# [2] {G(z1780)}  A
#
# [1] {-F(z1782), -G(z1782)}  A
#
# [1] {-F(z1784), -G(z1784)}  A
#
# [1] {-F(z1786), -G(z1786)}  A
#
# [1] {F(z1788)}  A
# [2] {G(z1789)}  A
#
# [1] {F(z1791)}  A
# [2] {G(z1792)}  A
#
# [1] {F(z1794)}  A
# [2] {G(z1795)}  A
#
# [1] {-F(z1797), -G(z1797)}  A
#
# [1] {-F(z1799), G(z1799)}  A
#
# [1] {-F(z1801), G(z1801)}  A
#
# [1] {F(z1803)}   A
# [2] {-G(z1804)}  A
#
# [1] {F(z1806)}   A
# [2] {-G(z1807)}  A
#
# [1] {F(z1809)}   A
# [2] {-G(z1810)}  A
#
# [1] {-F(z1812), G(z1812)}  A
#
# [1] {-F(z1814), G(z1814)}  A
#
# [1] {-F(z1816), G(z1816)}  A
#
# [1] {F(z1818)}   A
# [2] {-G(z1819)}  A
#
# [1] {F(z1821)}   A
# [2] {-G(z1822)}  A
#
# [1] {F(z1824)}   A
# [2] {-G(z1825)}  A
#
# [1] {-F(z1827), G(z1827)}  A
#
# [1] {F(z1829)}   A
# [2] {-G(z1830)}  A
#
# [1] {F(z1832)}   A
# [2] {-G(z1833)}  A
#
# [1] {-F(z1835), G(z1835)}  A
#
# [1] {-F(z1837), G(z1837)}  A
#
# [1] {-F(z1839), G(z1839)}  A
#
# [1] {F(z1841)}   A
# [2] {-G(z1842)}  A
#
# [1] {F(z1844)}   A
# [2] {-G(z1845)}  A
#
# [1] {F(z1847)}   A
# [2] {-G(z1848)}  A
#
# [1] {-F(z1850), G(z1850)}  A
#
# [1] {-F(z1852), G(z1852)}  A
#
# [1] {-F(z1854), G(z1854)}  A
#
# [1] {F(z1856)}   A
# [2] {-G(z1857)}  A
#
# [1] {-G(z1859), F(z1859)}  A
#
# [1] {-G(z1861), F(z1861)}  A
#
# [1] {G(z1863)}   A
# [2] {-F(z1864)}  A
#
# [1] {G(z1866)}   A
# [2] {-F(z1867)}  A
#
# [1] {G(z1869)}   A
# [2] {-F(z1870)}  A
#
# [1] {-G(z1872), F(z1872)}  A
#
# [1] {-G(z1874), F(z1874)}  A
#
# [1] {-G(z1876), F(z1876)}  A
#
# [1] {G(z1878)}   A
# [2] {-F(z1879)}  A
#
# [1] {-G(z1881), F(z1881)}  A
#
# [1] {-G(z1883), F(z1883)}  A
#
# [1] {G(z1885)}   A
# [2] {-F(z1886)}  A
#
# [1] {-G(z1888), F(z1888)}  A
#
# [1] {-G(z1890), F(z1890)}  A
#
# [1] {G(z1892)}   A
# [2] {-F(z1893)}  A
#
# [1] {G(z1895)}   A
# [2] {-F(z1896)}  A
#
# [1] {G(z1898)}   A
# [2] {-F(z1899)}  A
#
# [1] {-G(z1901), F(z1901)}  A
#
# [1] {-G(z1903), -F(z1903)}  A
#
# [1] {-G(z1905), -F(z1905)}  A
#
# [1] {G(z1907)}  A
# [2] {F(z1908)}  A
#
# [1] {G(z1910)}  A
# [2] {F(z1911)}  A
#
# [1] {G(z1913)}  A
# [2] {F(z1914)}  A
#
# [1] {-G(z1916), -F(z1916)}  A
#
# [1] {-G(z1918), -F(z1918)}  A
#
# [1] {-G(z1920), -F(z1920)}  A
#
# [1] {G(z1922)}  A
# [2] {F(z1923)}  A
#
# [1] {G(z1925)}  A
# [2] {F(z1926)}  A
#
# [1] {G(z1928)}  A
# [2] {F(z1929)}  A
#
# [1] {-G(z1931), -F(z1931)}  A
#
# [1] {G(z1933)}  A
# [2] {F(z1934)}  A
#
# [1] {G(z1936)}  A
# [2] {F(z1937)}  A
#
# [1] {-G(z1939), -F(z1939)}  A
#
# [1] {G(z1941)}   A
# [2] {-G(z1942)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1944), G(z1944)}  A Tautology
#
# [1] {G(z1946)}   A
# [2] {-G(z1947)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1949), G(z1949)}  A Tautology
#
# [1] {-G(z1951), G(z1951)}  A Tautology
#
# [1] {G(z1953)}   A
# [2] {-G(z1954)}  A
# [3] {}           (1, 2)
#
# [1] {G(z1956)}   A
# [2] {-G(z1957)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1959), G(z1959)}  A Tautology
#
# [1] {G(z1961)}   A
# [2] {-G(z1962)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1964), G(z1964)}  A Tautology
#
# [1] {-G(z1966), G(z1966)}  A Tautology
#
# [1] {G(z1968)}   A
# [2] {-G(z1969)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1971), G(z1971)}  A Tautology
#
# [1] {-G(z1973), G(z1973)}  A Tautology
#
# [1] {G(z1975)}   A
# [2] {-G(z1976)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1978), G(z1978)}  A Tautology
#
# [1] {-G(z1980), G(z1980)}  A Tautology
#
# [1] {G(z1982)}   A
# [2] {-G(z1983)}  A
# [3] {}           (1, 2)
#
# [1] {G(z1985)}   A
# [2] {-G(z1986)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1988), G(z1988)}  A Tautology
#
# [1] {G(z1990)}   A
# [2] {-G(z1991)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1993), -G(z1993)}  A
#
# [1] {-G(z1995), -G(z1995)}  A
#
# [1] {G(z1997)}  A
# [2] {G(z1998)}  A
#
# [1] {G(z2000)}  A
# [2] {G(z2001)}  A
#
# [1] {G(z2003)}  A
# [2] {G(z2004)}  A
#
# [1] {-G(z2006), -G(z2006)}  A
#
# [1] {G(z2008)}  A
# [2] {G(z2009)}  A
#
# [1] {G(z2011)}  A
# [2] {G(z2012)}  A
#
# [1] {-G(z2014), -G(z2014)}  A
#
# [1] {G(z2016)}  A
# [2] {G(z2017)}  A
#
# [1] {G(z2019)}  A
# [2] {G(z2020)}  A
#
# [1] {-G(z2022), -G(z2022)}  A
#
# [1] {-G(z2024), -G(z2024)}  A
#
# [1] {-G(z2026), -G(z2026)}  A
#
# [1] {G(z2028)}  A
# [2] {G(z2029)}  A
#
# [1] {G(z2031)}  A
# [2] {G(z2032)}  A
#
# [1] {G(z2034)}  A
# [2] {G(z2035)}  A
#
# [1] {-G(z2037), -G(z2037)}  A
#
# [1] {-G(z2039), -G(z2039)}  A
#
# [1] {-G(z2041), -G(z2041)}  A
#
# [1] {G(z2043)}  A
# [2] {G(z2044)}  A
#
# [1] {-G(z2046), -F(z2046)}  A
#
# [1] {-G(z2048), -F(z2048)}  A
#
# [1] {G(z2050)}  A
# [2] {F(z2051)}  A
#
# [1] {G(z2053)}  A
# [2] {F(z2054)}  A
#
# [1] {G(z2056)}  A
# [2] {F(z2057)}  A
#
# [1] {-G(z2059), -F(z2059)}  A
#
# [1] {-G(z2061), -F(z2061)}  A
#
# [1] {-G(z2063), -F(z2063)}  A
#
# [1] {G(z2065)}  A
# [2] {F(z2066)}  A
#
# [1] {-G(z2068), -F(z2068)}  A
#
# [1] {-G(z2070), -F(z2070)}  A
#
# [1] {G(z2072)}  A
# [2] {F(z2073)}  A
#
# [1] {G(z2075)}  A
# [2] {F(z2076)}  A
#
# [1] {G(z2078)}  A
# [2] {F(z2079)}  A
#
# [1] {-G(z2081), -F(z2081)}  A
#
# [1] {-G(z2083), -F(z2083)}  A
#
# [1] {-G(z2085), -F(z2085)}  A
#
# [1] {G(z2087)}  A
# [2] {F(z2088)}  A
#
# [1] {-G(z2090), F(z2090)}  A
#
# [1] {-G(z2092), F(z2092)}  A
#
# [1] {G(z2094)}   A
# [2] {-F(z2095)}  A
#
# [1] {G(z2097)}   A
# [2] {-F(z2098)}  A
#
# [1] {G(z2100)}   A
# [2] {-F(z2101)}  A
#
# [1] {-G(z2103), F(z2103)}  A
#
# [1] {-G(z2105), F(z2105)}  A
#
# [1] {-G(z2107), F(z2107)}  A
#
# [1] {G(z2109)}   A
# [2] {-F(z2110)}  A
#
#
# [1] {-G(z2946)}  A
# [2] {-F(z2947)}  A
#
# [1] {-G(z2949)}  A
# [2] {-F(z2950)}  A
#
# [1] {G(z2952), F(z2952)}  A
#
# [1] {G(z2954), F(z2954)}  A
#
# [1] {G(z2956), F(z2956)}  A
#
# [1] {-G(z2958)}  A
# [2] {-F(z2959)}  A
#
# [1] {-G(z2961)}  A
# [2] {-F(z2962)}  A
#
# [1] {-G(z2964)}  A
# [2] {-F(z2965)}  A
#
# [1] {G(z2967), F(z2967)}  A
#
# [1] {G(z2969), F(z2969)}  A
#
# [1] {G(z2971), F(z2971)}  A
#
# [1] {-G(z2973)}  A
# [2] {-F(z2974)}  A
#
# [1] {-G(z2976)}  A
# [2] {-F(z2977)}  A
#
# [1] {-G(z2979)}  A
# [2] {-F(z2980)}  A
#
# [1] {G(z2982), F(z2982)}  A
#
# [1] {G(z2984), F(z2984)}  A
#
# [1] {G(z2986), F(z2986)}  A
#
# [1] {-G(z2988)}  A
# [2] {-F(z2989)}  A
#
# [1] {-G(z2991)}  A
# [2] {G(z2992)}   A
# [3] {}           (1, 2)
#
# [1] {G(z2994), -G(z2994)}  A Tautology
#
# [1] {-G(z2996)}  A
# [2] {G(z2997)}   A
# [3] {}           (1, 2)
#
# [1] {G(z2999), -G(z2999)}  A Tautology
#
# [1] {G(z3001), -G(z3001)}  A Tautology
#
# [1] {-G(z3003)}  A
# [2] {G(z3004)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z3006)}  A
# [2] {G(z3007)}   A
# [3] {}           (1, 2)
#
# [1] {G(z3009), -G(z3009)}  A Tautology
#
# [1] {-G(z3011)}  A
# [2] {G(z3012)}   A
# [3] {}           (1, 2)
#
# [1] {G(z3014), -G(z3014)}  A Tautology
#
# [1] {G(z3016), -G(z3016)}  A Tautology
#
# [1] {-G(z3018)}  A
# [2] {G(z3019)}   A
# [3] {}           (1, 2)
#
# [1] {G(z3021), -G(z3021)}  A Tautology
#
# [1] {G(z3023), -G(z3023)}  A Tautology
#
# [1] {-G(z3025)}  A
# [2] {G(z3026)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z3028)}  A
# [2] {G(z3029)}   A
# [3] {}           (1, 2)
#
# [1] {G(z3031), -G(z3031)}  A Tautology
#
# [1] {-G(z3033)}  A
# [2] {G(z3034)}   A
# [3] {}           (1, 2)
#
# [1] {G(z3036), -G(z3036)}  A Tautology
#
# [1] {G(z3038), -G(z3038)}  A Tautology
#
# [1] {-G(z3040)}  A
# [2] {G(z3041)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z3043)}  A
# [2] {G(z3044)}   A
# [3] {}           (1, 2)
#
# [1] {G(z3046), -G(z3046)}  A Tautology
#
# [1] {-G(z3048)}  A
# [2] {G(z3049)}   A
# [3] {}           (1, 2)
#
# [1] {G(z3051), G(z3051)}  A
#
# [1] {G(z3053), G(z3053)}  A
#
# [1] {-G(z3055)}  A
# [2] {-G(z3056)}  A
#
# [1] {-G(z3058)}  A
# [2] {-G(z3059)}  A
#
# [1] {-G(z3061)}  A
# [2] {-G(z3062)}  A
#
# [1] {G(z3064), G(z3064)}  A
#
# [1] {G(z3066), G(z3066)}  A
#
# [1] {G(z3068), G(z3068)}  A
#
# [1] {-G(z3070)}  A
# [2] {-G(z3071)}  A
#
# [1] {-G(z3073)}  A
# [2] {-G(z3074)}  A
#
# [1] {-G(z3076)}  A
# [2] {-G(z3077)}  A
#
# [1] {G(z3079), G(z3079)}  A
#
# [1] {-G(z3081)}  A
# [2] {-G(z3082)}  A
#
# [1] {-G(z3084)}  A
# [2] {-G(z3085)}  A
#
# [1] {G(z3087), G(z3087)}  A
#
# [1] {G(z3089), G(z3089)}  A
#
# [1] {G(z3091), G(z3091)}  A
#
# [1] {-G(z3093)}  A
# ...
#
# [1] {-G(z6404)}  A
# [2] {G(z6405)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z
# [1] {-G(z7375), -F(z7375)}  A
#
# [1] {-G(z7377), -F(z7377)}  A
#
# [1] {-G(z7379), -F(z7379)}  A
#
# [1] {G(z7381)}  A
# [2] {F(z7382)}  A
#
# [1] {G(z7384)}  A
# [2] {F(z7385)}  A
#
# [1] {G(z7387)}  A
# [2] {F(z7388)}  A
#
# [1] {-G(z7390), -F(z7390)}  A
#
# [1] {-G(z7392), -F(z7392)}  A
#
# [1] {-G(z7394), -F(z7394)}  A
#
# [1] {G(z7396)}  A
# [2] {F(z7397)}  A
#
# [1] {-G(z7399), -F(z7399)}  A
#
# [1] {-G(z7401), -F(z7401)}  A
#
# [1] {G(z7403)}  A
# [2] {F(z7404)}  A
#
# [1] {G(z7406)}  A
# [2] {F(z7407)}  A
#
# [1] {G(z7409)}  A
# [2] {F(z7410)}  A
#
# [1] {-G(z7412), -F(z7412)}  A
#
# [1] {-G(z7414), -F(z7414)}  A
#
# [1] {-G(z7416), -F(z7416)}  A
#
# [1] {G(z7418)}  A
# [2] {F(z7419)}  A
#
# [1] {G(z7421)}  A
# [2] {F(z7422)}  A
#
# [1] {G(z7424)}  A
# [2] {F(z7425)}  A
#
# [1] {-G(z7427), -F(z7427)}  A

# %%
tautologyCounts_df = pd.DataFrame()
tautologyCounts_df["tautologyCounts"] = pd.DataFrame(numTautologies)
tautologyCounts_df = tautologyCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
tautologyCounts_df["Correct"] = output_dataset['Correct']
tautologyCounts_df
# Out:
#        tautologyCounts  Correct
# 80000            False     True
# 80001            False    False
# 80002            False     True
# 80003            False    False
# 80004            False    False
# ...                ...      ...
# 80995            False     True
# 80996            False     True
# 80997            False    False
# 80998            False     True
# 80999            False    False
#
# [1000 rows x 2 columns]

# %%
tautologyCounts = tautologyCounts_df.groupby(['Correct', 'tautologyCounts']).size()
tautologyCounts
# Out:
# Correct  tautologyCounts
# False    False              327
#          True               112
# True     False              550
#          True                11
# dtype: int64

# %%
dfp = tautologyCounts_df.pivot_table(index='tautologyCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
17/142
# Out:
# 0.11971830985915492

# %%
106/735
# Out:
# 0.14421768707482993

# %%
contradictionCounts_df = pd.DataFrame()
contradictionCounts_df["contradictionCounts"] = pd.DataFrame(numContradictions)
contradictionCounts_df = contradictionCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
contradictionCounts_df["Correct"] = output_dataset['Correct']
contradictionCounts_df
# Out:
#        contradictionCounts  Correct
# 80000                False     True
# 80001                False    False
# 80002                False     True
# 80003                False    False
# 80004                False    False
# ...                    ...      ...
# 80995                False     True
# 80996                False     True
# 80997                False    False
# 80998                False     True
# 80999                False    False
#
# [1000 rows x 2 columns]

# %%
contradictionCounts = contradictionCounts_df.groupby(['Correct', 'contradictionCounts']).size()
contradictionCounts
# Out:
# Correct  contradictionCounts
# False    False                  432
#          True                     7
# True     False                  450
#          True                   111
# dtype: int64

# %%
dfp = contradictionCounts_df.pivot_table(index='contradictionCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()
