# %% [markdown]
# ## Quantitative Analysis

# %% [markdown]
# i.e. here, I perform a quantitative analysis of the training output datasets: are the trained models able to work better (or worse) under certain circumstances?
# That is:
# - with a certain type of quantifier? (all, exists) (is a certain type of quantifier harder?)
# - with a certain number of keys? (generally -> or specifically: with a certain number of predicates? / constants?) (is more keys / predicates / constants harder?)
# - with a certain number of constants?
# - with a certain number of predicates?
# - with a certain size of the world model? (is a bigger world model harder?)
# - with a certain number of operators? (is more operators harder?)
# - with a certain type of operator? (negation, implication, and-operator) -> especially: is there negation in front of quantifiers or not? // using only no operators vs. unary vs. binary operators // (is a certain type of operator harder (none, unary, binary)? is negation in front of quantifiers harder?)
# - etc. (e.g. do the models tend to produce tautologies / contradictions?)
#
# (dazu sowohl Output Datensatz als auch Input Datensatz laden, über id Mappen!!)
# => dann noch: weitere Spalten miteinbeziehen: correctIncorrect vs. Gibberish.
#
# - for evaluation, we chose the datapoints: 80000:81000
# - manche der unten stehenden Evals machen gegeben der Task keinen Sinn!!
#     - Task 1: Input:  World Model + Keys + Satisfied => also: macht nur world model count, constants count, keys count, predicates count Sinn. Aber nicht: quantifier, operator count, operator type.
#     - Task 2: Input: Formula + Satisfied => also: umgekehrt wie task 1: es macht nur: operator count, operator type, quantifier Sinn, (predicates count). Aber nicht: world model count, constants count, keys count.
#     - Task 3: Input: Formula + Keys + World Model => also: macht alles Sinn.

# %%
import json
import collections
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = 'wizard-15b_trained_on_t1t2t3_task1.json' #TODO: change 
output_dataset = pd.read_json('../results/training-eval/' + filename)
filename = 'base_pred_logic_data.json'
base_dataset = pd.read_json('../datasets/' + filename)

# %%
output_dataset
# Out:
#                                              Predictions   Target-sat
# 80000  all x.-(G(x) -> F(x))\n\nQuestion:\n\nHere is ...  unsatisfied  \
# 80001  exists x.-(G(x) -> -F(x))\n\nNote: This formul...    satisfied
# 80002  all x.-(G(x) -> F(x))\n\nQuestion:\n\nHere is ...  unsatisfied
# 80003  exists x.-(G(x) -> F(x))\n\nQuestion:\n\nHere ...    satisfied
# 80004  exists x.-(F(x) -> G(x))\n\nNote: This formula...    satisfied
# ...                                                  ...          ...
# 80995  all x.-(F(x) -> G(x))\n\nQuestion:\n\nHere is ...  unsatisfied
# 80996  all x.-(G(x) -> F(x))\n\nQuestion:\n\nHere is ...  unsatisfied
# 80997  exists x.-(F(x) -> -G(x))\n\nNote: This formul...    satisfied
# 80998  all x.-(G(x) -> F(x))\n\nQuestion:\n\nHere is ...  unsatisfied
# 80999  exists x.-(G(x) -> -F(x))\n\nNote: This formul...    satisfied
#
#                                                Valuation  Correct  Gibberish
# 80000  [[b, Aubrielle], [s, Wynter], [g, Giovanna], [...     True      False
# 80001  [[l, Phoenix], [i, Rudy], [b, Kolten], [s, Dal...     True      False
# 80002  [[f, Ivan], [k, Hayley], [l, Gustavo], [G, [f]...     True      False
# 80003                    [[q, Nova], [G, [q]], [F, [q]]]    False      False
# 80004  [[e, Beckett], [o, Lia], [b, Stella], [q, Nanc...     True      False
# ...                                                  ...      ...        ...
# 80995  [[d, Dulce], [k, Ezra], [h, Mateo], [s, Bentle...     True      False
# 80996  [[r, Abigail], [c, Lennon], [n, Salma], [G, [r...     True      False
# 80997    [[j, Gatlin], [s, Avianna], [G, [s]], [F, [j]]]    False      False
# 80998  [[l, Edith], [e, Trace], [f, Emery], [b, Harry...     True      False
# 80999  [[f, Judith], [k, Ellie], [q, Barrett], [p, Ro...    False      False
#
# [1000 rows x 5 columns]

# %%
# subset:
base_dataset = base_dataset.iloc[80000:81000]
len(base_dataset)
# Out:
# 1000

# %%
base_dataset
# Out:
#                           Formula Predicates Variables Operators Quantifiers
# 80000      all x.-(F(x) -> -G(x))     [G, F]       [x]   [->, -]         all  \
# 80001     -all x.-(F(x) -> -G(x))     [G, F]       [x]   [->, -]         all
# 80002        all x.(F(x) & -G(x))     [G, F]       [x]    [&, -]         all
# 80003       -all x.(F(x) & -G(x))     [G, F]       [x]    [&, -]         all
# 80004     exists x.(F(x) & -G(x))     [G, F]       [x]    [&, -]      exists
# ...                           ...        ...       ...       ...         ...
# 80995   -exists x.(G(x) -> -F(x))     [G, F]       [x]    [>, -]      exists
# 80996      all x.-(G(x) -> -F(x))     [G, F]       [x]   [->, -]         all
# 80997     -all x.-(G(x) -> -F(x))     [G, F]       [x]   [->, -]         all
# 80998   exists x.-(G(x) -> -F(x))     [G, F]       [x]   [->, -]      exists
# 80999  -exists x.-(G(x) -> -F(x))     [G, F]       [x]   [->, -]      exists
#
#                                   P_mapping
# 80000          {'G': 'Joyful', 'F': 'Calm'}  \
# 80001       {'G': 'Bothered', 'F': 'Witty'}
# 80002  {'G': 'Bothered', 'F': 'Supportive'}
# 80003  {'G': 'Arrogant', 'F': 'Mysterious'}
# 80004      {'G': 'Jovial', 'F': 'Creative'}
# ...                                     ...
# 80995  {'G': 'Antagonistic', 'F': 'Humble'}
# 80996        {'G': 'Heroic', 'F': 'Afraid'}
# 80997      {'G': 'Earnest', 'F': 'Panicky'}
# 80998   {'G': 'Alarmed', 'F': 'Thoughtful'}
# 80999           {'G': 'Afraid', 'F': 'Sad'}
#
#                                                C_mapping
# 80000  {'b': 'Aubrielle', 's': 'Wynter', 'g': 'Giovan...  \
# 80001  {'l': 'Phoenix', 'i': 'Rudy', 'b': 'Kolten', '...
# 80002       {'f': 'Ivan', 'k': 'Hayley', 'l': 'Gustavo'}
# 80003                                      {'q': 'Nova'}
# 80004  {'e': 'Beckett', 'o': 'Lia', 'b': 'Stella', 'q...
# ...                                                  ...
# 80995  {'d': 'Dulce', 'k': 'Ezra', 'h': 'Mateo', 's':...
# 80996      {'r': 'Abigail', 'c': 'Lennon', 'n': 'Salma'}
# 80997                    {'j': 'Gatlin', 's': 'Avianna'}
# 80998  {'l': 'Edith', 'e': 'Trace', 'f': 'Emery', 'b'...
# 80999  {'f': 'Judith', 'k': 'Ellie', 'q': 'Barrett', ...
#
#                                                     Keys
# 80000  G: Joyful. F: Calm. b: Aubrielle. s: Wynter. g...  \
# 80001  G: Bothered. F: Witty. l: Phoenix. i: Rudy. b:...
# 80002  G: Bothered. F: Supportive. f: Ivan. k: Hayley...
# 80003               G: Arrogant. F: Mysterious. q: Nova.
# 80004  G: Jovial. F: Creative. e: Beckett. o: Lia. b:...
# ...                                                  ...
# 80995  G: Antagonistic. F: Humble. d: Dulce. k: Ezra....
# 80996  G: Heroic. F: Afraid. r: Abigail. c: Lennon. n...
# 80997     G: Earnest. F: Panicky. j: Gatlin. s: Avianna.
# 80998  G: Alarmed. F: Thoughtful. l: Edith. e: Trace....
# 80999  G: Afraid. F: Sad. f: Judith. k: Ellie. q: Bar...
#
#                                                    Names
# 80000  [Aubrielle, Wynter, Giovanna, Dalary, Paislee,...  \
# 80001     [Phoenix, Rudy, Kolten, Dalton, Adley, Carson]
# 80002                            [Ivan, Hayley, Gustavo]
# 80003                                             [Nova]
# 80004  [Beckett, Lia, Stella, Nancy, Calliope, Chase,...
# ...                                                  ...
# 80995  [Dulce, Ezra, Mateo, Bentley, Adrian, Poppy, J...
# 80996                           [Abigail, Lennon, Salma]
# 80997                                  [Gatlin, Avianna]
# 80998  [Edith, Trace, Emery, Harry, Anika, Taliyah, M...
# 80999                    [Judith, Ellie, Barrett, Roman]
#
#                    Adjectives
# 80000          [Joyful, Calm]  \
# 80001       [Bothered, Witty]
# 80002  [Bothered, Supportive]
# 80003  [Arrogant, Mysterious]
# 80004      [Jovial, Creative]
# ...                       ...
# 80995  [Antagonistic, Humble]
# 80996        [Heroic, Afraid]
# 80997      [Earnest, Panicky]
# 80998   [Alarmed, Thoughtful]
# 80999           [Afraid, Sad]
#
#                                              World Model
# 80000   Aubrielle is Joyful. Wynter is not Joyful. Gi...  \
# 80001   Phoenix is Bothered. Rudy is not Bothered. Ko...
# 80002   Ivan is Bothered. Hayley is Bothered. Gustavo...
# 80003              Nova is Arrogant. Nova is Mysterious.
# 80004   Beckett is not Jovial. Lia is Jovial. Stella ...
# ...                                                  ...
# 80995   Dulce is not Antagonistic. Ezra is not Antago...
# 80996   Abigail is Heroic. Lennon is Heroic. Salma is...
# 80997   Gatlin is not Earnest. Avianna is Earnest. Ga...
# 80998   Edith is not Alarmed. Trace is not Alarmed. E...
# 80999   Judith is Afraid. Ellie is not Afraid. Barret...
#
#                                                Valuation    Satisfied
# 80000  [[b, Aubrielle], [s, Wynter], [g, Giovanna], [...  unsatisfied
# 80001  [[l, Phoenix], [i, Rudy], [b, Kolten], [s, Dal...    satisfied
# 80002  [[f, Ivan], [k, Hayley], [l, Gustavo], [G, [f]...  unsatisfied
# 80003                    [[q, Nova], [G, [q]], [F, [q]]]    satisfied
# 80004  [[e, Beckett], [o, Lia], [b, Stella], [q, Nanc...    satisfied
# ...                                                  ...          ...
# 80995  [[d, Dulce], [k, Ezra], [h, Mateo], [s, Bentle...  unsatisfied
# 80996  [[r, Abigail], [c, Lennon], [n, Salma], [G, [r...  unsatisfied
# 80997    [[j, Gatlin], [s, Avianna], [G, [s]], [F, [j]]]    satisfied
# 80998  [[l, Edith], [e, Trace], [f, Emery], [b, Harry...  unsatisfied
# 80999  [[f, Judith], [k, Ellie], [q, Barrett], [p, Ro...    satisfied
#
# [1000 rows x 13 columns]

# %% [markdown]
# #### Descriptive Statistics

# %%
satCounts = base_dataset['Satisfied'].value_counts()
satCounts
# Out:
# Satisfied
# satisfied      505
# unsatisfied    495
# Name: count, dtype: int64

# %%
# First: show descriptive statistics of evaluation dataset:
# number of quantifiers: all, exists
quantifiersCounts = base_dataset['Quantifiers'].value_counts()
quantifiersCounts
# Out:
# Quantifiers
# exists    503
# all       497
# Name: count, dtype: int64

# %%
# distribution of predicates
predicatesCounts = base_dataset['Predicates'].value_counts() # then add the singular F and G to one line
predicatesCounts
# Out:
# Predicates
# [G, F]    457
# [G]       281
# [F]       262
# Name: count, dtype: int64

# %%
# distribution of constants 
oldConstants = base_dataset['Names']
constants = []
for con in oldConstants:
    constants.append(len(con))
constantsCounts = collections.Counter(constants) # the keys() is what is counted, and the values() is the count
constantsCounts
# Out:
# Counter({7: 124,
#          6: 114,
#          3: 107,
#          1: 52,
#          5: 105,
#          10: 112,
#          2: 71,
#          9: 109,
#          4: 106,
#          8: 100})

# %%
temp = pd.DataFrame(list(zip(constantsCounts.keys(), constantsCounts.values())), columns=['Number_of_constants','Count']).sort_values('Number_of_constants')
temp.plot(kind="bar", x = "Number_of_constants")
# Out:
# <Axes: xlabel='Number_of_constants'>

# %%
# distribution of keys
keys_list = base_dataset['Keys']
keysTemp = []
for keys in keys_list:
    keysTemp.append(keys.count(':'))
keysCounts = collections.Counter(keysTemp)
keysCounts
# Out:
# Counter({9: 112,
#          8: 122,
#          5: 99,
#          3: 63,
#          7: 107,
#          12: 50,
#          4: 88,
#          11: 119,
#          6: 114,
#          10: 95,
#          2: 31})

# %%
temp = pd.DataFrame(list(zip(keysCounts.keys(), keysCounts.values())), columns=['Number_of_keys','Count']).sort_values('Number_of_keys')
temp.plot(kind="bar", x = "Number_of_keys")
# Out:
# <Axes: xlabel='Number_of_keys'>

# %%
# distribution of world model size
worldModel_list = base_dataset['World Model']
wmTemp = []
for wm in worldModel_list:
    wmTemp.append(wm.count('.'))
worldModelCounts = collections.Counter(wmTemp)
worldModelCounts
# Out:
# Counter({14: 55,
#          12: 53,
#          6: 109,
#          2: 63,
#          10: 108,
#          20: 50,
#          4: 80,
#          18: 57,
#          8: 112,
#          16: 43,
#          7: 69,
#          1: 31,
#          9: 52,
#          5: 59,
#          3: 59})

# %%
temp = pd.DataFrame(list(zip(worldModelCounts.keys(), worldModelCounts.values())), columns=['Number_of_Sentences','Count']).sort_values('Number_of_Sentences')
temp.plot(kind="bar", x = "Number_of_Sentences")
# Out:
# <Axes: xlabel='Number_of_Sentences'>

# %%
# generally: count all negations, implications, and-operators individually for each formula (string-find-count).
# from this deduce another list: total number of operators => plot this count. (is more operators harder?)
numNegations = []
numImplications = []
numAnds = []

formula_list = base_dataset['Formula']
for formula in formula_list:
    numNegations.append(formula.count("-"))
    numImplications.append(formula.count(">"))
    numAnds.append(formula.count("&"))

numTotalOperators = [a + b + c for (a, b, c) in zip(numNegations,numImplications,numAnds)]

# %%
negationCounts = collections.Counter(numNegations)
negationCounts
# Out:
# Counter({3: 293, 4: 141, 1: 184, 2: 309, 0: 45, 5: 28})

# %%
temp = pd.DataFrame(list(zip(negationCounts.keys(), negationCounts.values())), columns=['Number_of_Negations','Count']).sort_values('Number_of_Negations')
temp.plot(kind="bar", x = "Number_of_Negations")
# Out:
# <Axes: xlabel='Number_of_Negations'>

# %%
implicationCounts = collections.Counter(numImplications)
implicationCounts
# Out:
# Counter({1: 468, 0: 532})

# %%
andCounts = collections.Counter(numAnds)
andCounts
# Out:
# Counter({0: 526, 1: 474})

# %%
totalOperatorCounts = collections.Counter(numTotalOperators)
totalOperatorCounts
# Out:
# Counter({4: 293, 5: 141, 2: 167, 3: 296, 1: 60, 6: 28, 0: 15})

# %%
temp = pd.DataFrame(list(zip(totalOperatorCounts.keys(), totalOperatorCounts.values())), columns=['Number_of_Operators','Count']).sort_values('Number_of_Operators')
temp.plot(kind="bar", x = "Number_of_Operators")
# Out:
# <Axes: xlabel='Number_of_Operators'>

# %%
# (is a certain type of operator harder (none, unary, binary, unary + binary)?
# none is in totalOperatorCounts 
# noOperators = [True if x == 0 else False for x in totalOperatorCounts]
# <- this is not really needed, see above.

# %%
# how many times there is negation in front of quantifiers vs. not (is negation in front of quantifiers harder?)
numNegationInFront = []
for formula in formula_list:
    if formula[0] == "-":
        numNegationInFront.append(True)
    else:
        numNegationInFront.append(False)
negationInFrontCounts = collections.Counter(numNegationInFront)
negationInFrontCounts
# Out:
# Counter({False: 506, True: 494})

# %%
# unary is negationCounts > 0 und implicationCounts == 0 und andCounts == 0.
# binary is negationCounts == 0 und implicationCounts > 0 oder andCounts > 0.
# unary + binary == 
unaryOperators = []
binaryOperators = []
unaryBinaryOperators = []
for nega, impl, andop in zip(numNegations, numImplications, numAnds):
    if nega > 0:
        binaryOperators.append(False)
        if impl == 0 and andop == 0:
            unaryOperators.append(True)
            unaryBinaryOperators.append(False)
        else:
            unaryOperators.append(False)
            unaryBinaryOperators.append(True)
    else:
        binaryOperators.append(True)
        unaryBinaryOperators.append(False)
        unaryOperators.append(False)

# %%
unaryOperatorsCounts = collections.Counter(unaryOperators)
unaryOperatorsCounts
# Out:
# Counter({False: 957, True: 43})

# %%
binaryOperatorsCounts = collections.Counter(binaryOperators)
binaryOperatorsCounts
# Out:
# Counter({False: 955, True: 45})

# %%
unaryBinaryOperatorsCounts = collections.Counter(unaryBinaryOperators)
unaryBinaryOperatorsCounts
# Out:
# Counter({True: 912, False: 88})

# %% [markdown]
# #### Dataset specific statistics

# %% [markdown]
# assume, we have two more columns in the output dataset: Correct (True / False), Gibberish (True / False).
#
# But for now, just create bar charts for IncorrectCorrect.

# %%
output_dataset.head()
# Out:
#                                              Predictions   Target-sat
# 80000  all x.-(G(x) -> F(x))\n\nQuestion:\n\nHere is ...  unsatisfied  \
# 80001  exists x.-(G(x) -> -F(x))\n\nNote: This formul...    satisfied
# 80002  all x.-(G(x) -> F(x))\n\nQuestion:\n\nHere is ...  unsatisfied
# 80003  exists x.-(G(x) -> F(x))\n\nQuestion:\n\nHere ...    satisfied
# 80004  exists x.-(F(x) -> G(x))\n\nNote: This formula...    satisfied
#
#                                                Valuation  Correct  Gibberish
# 80000  [[b, Aubrielle], [s, Wynter], [g, Giovanna], [...     True      False
# 80001  [[l, Phoenix], [i, Rudy], [b, Kolten], [s, Dal...     True      False
# 80002  [[f, Ivan], [k, Hayley], [l, Gustavo], [G, [f]...     True      False
# 80003                    [[q, Nova], [G, [q]], [F, [q]]]    False      False
# 80004  [[e, Beckett], [o, Lia], [b, Stella], [q, Nanc...     True      False

# %%
s = pd.Series([i for i in range(80000, 81000, 1)])
base_dataset.set_index([s])
base_dataset.head()
# Out:
#                        Formula Predicates Variables Operators Quantifiers
# 80000   all x.-(F(x) -> -G(x))     [G, F]       [x]   [->, -]         all  \
# 80001  -all x.-(F(x) -> -G(x))     [G, F]       [x]   [->, -]         all
# 80002     all x.(F(x) & -G(x))     [G, F]       [x]    [&, -]         all
# 80003    -all x.(F(x) & -G(x))     [G, F]       [x]    [&, -]         all
# 80004  exists x.(F(x) & -G(x))     [G, F]       [x]    [&, -]      exists
#
#                                   P_mapping
# 80000          {'G': 'Joyful', 'F': 'Calm'}  \
# 80001       {'G': 'Bothered', 'F': 'Witty'}
# 80002  {'G': 'Bothered', 'F': 'Supportive'}
# 80003  {'G': 'Arrogant', 'F': 'Mysterious'}
# 80004      {'G': 'Jovial', 'F': 'Creative'}
#
#                                                C_mapping
# 80000  {'b': 'Aubrielle', 's': 'Wynter', 'g': 'Giovan...  \
# 80001  {'l': 'Phoenix', 'i': 'Rudy', 'b': 'Kolten', '...
# 80002       {'f': 'Ivan', 'k': 'Hayley', 'l': 'Gustavo'}
# 80003                                      {'q': 'Nova'}
# 80004  {'e': 'Beckett', 'o': 'Lia', 'b': 'Stella', 'q...
#
#                                                     Keys
# 80000  G: Joyful. F: Calm. b: Aubrielle. s: Wynter. g...  \
# 80001  G: Bothered. F: Witty. l: Phoenix. i: Rudy. b:...
# 80002  G: Bothered. F: Supportive. f: Ivan. k: Hayley...
# 80003               G: Arrogant. F: Mysterious. q: Nova.
# 80004  G: Jovial. F: Creative. e: Beckett. o: Lia. b:...
#
#                                                    Names
# 80000  [Aubrielle, Wynter, Giovanna, Dalary, Paislee,...  \
# 80001     [Phoenix, Rudy, Kolten, Dalton, Adley, Carson]
# 80002                            [Ivan, Hayley, Gustavo]
# 80003                                             [Nova]
# 80004  [Beckett, Lia, Stella, Nancy, Calliope, Chase,...
#
#                    Adjectives
# 80000          [Joyful, Calm]  \
# 80001       [Bothered, Witty]
# 80002  [Bothered, Supportive]
# 80003  [Arrogant, Mysterious]
# 80004      [Jovial, Creative]
#
#                                              World Model
# 80000   Aubrielle is Joyful. Wynter is not Joyful. Gi...  \
# 80001   Phoenix is Bothered. Rudy is not Bothered. Ko...
# 80002   Ivan is Bothered. Hayley is Bothered. Gustavo...
# 80003              Nova is Arrogant. Nova is Mysterious.
# 80004   Beckett is not Jovial. Lia is Jovial. Stella ...
#
#                                                Valuation    Satisfied
# 80000  [[b, Aubrielle], [s, Wynter], [g, Giovanna], [...  unsatisfied
# 80001  [[l, Phoenix], [i, Rudy], [b, Kolten], [s, Dal...    satisfied
# 80002  [[f, Ivan], [k, Hayley], [l, Gustavo], [G, [f]...  unsatisfied
# 80003                    [[q, Nova], [G, [q]], [F, [q]]]    satisfied
# 80004  [[e, Beckett], [o, Lia], [b, Stella], [q, Nanc...    satisfied

# %%
# - with a certain type of quantifier? (all, exists)
temp_df = pd.concat([output_dataset['Correct'], base_dataset['Quantifiers']], axis=1)
temp_df.head()
# Out:
#        Correct Quantifiers
# 80000     True         all
# 80001     True         all
# 80002     True         all
# 80003    False         all
# 80004     True      exists

# %%
quantifierCounts = temp_df.groupby(['Correct', 'Quantifiers']).size()
quantifierCounts
# Out:
# Correct  Quantifiers
# False    all            148
#          exists         161
# True     all            349
#          exists         342
# dtype: int64

# %%
keyCounts_df = pd.DataFrame()
keyCounts_df["keyCounts"] = pd.DataFrame(keysTemp)
keyCounts_df = keyCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
keyCounts_df["Correct"] = output_dataset['Correct']
keyCounts_df
# Out:
#        keyCounts  Correct
# 80000          9     True
# 80001          8     True
# 80002          5     True
# 80003          3    False
# 80004          9     True
# ...          ...      ...
# 80995         10     True
# 80996          5     True
# 80997          4    False
# 80998         11     True
# 80999          6    False
#
# [1000 rows x 2 columns]

# %%
keyCounts = keyCounts_df.groupby(['Correct', 'keyCounts']).size()
keyCounts
# Out:
# Correct  keyCounts
# False    2             6
#          3            26
#          4            30
#          5            32
#          6            39
#          7            33
#          8            33
#          9            33
#          10           20
#          11           41
#          12           16
# True     2            25
#          3            37
#          4            58
#          5            67
#          6            75
#          7            74
#          8            89
#          9            79
#          10           75
#          11           78
#          12           34
# dtype: int64

# %%
dfp = keyCounts_df.pivot_table(index='keyCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
# - with a certain number of constants?
constantsCounts_df = pd.DataFrame()
constantsCounts_df["constantCounts"] = pd.DataFrame(constants)
constantsCounts_df = constantsCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
constantsCounts_df["Correct"] = output_dataset['Correct']
constantsCounts_df
# Out:
#        constantCounts  Correct
# 80000               7     True
# 80001               6     True
# 80002               3     True
# 80003               1    False
# 80004               7     True
# ...               ...      ...
# 80995               8     True
# 80996               3     True
# 80997               2    False
# 80998               9     True
# 80999               4    False
#
# [1000 rows x 2 columns]

# %%
constantCounts = constantsCounts_df.groupby(['Correct', 'constantCounts']).size()
constantCounts
# Out:
# Correct  constantCounts
# False    1                 20
#          2                 25
#          3                 34
#          4                 34
#          5                 38
#          6                 33
#          7                 29
#          8                 28
#          9                 26
#          10                42
# True     1                 32
#          2                 46
#          3                 73
#          4                 72
#          5                 67
#          6                 81
#          7                 95
#          8                 72
#          9                 83
#          10                70
# dtype: int64

# %%
dfp = constantsCounts_df.pivot_table(index='constantCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
# - with a certain number of predicates?

# %%
oldpredicates = base_dataset['Predicates']
predicates = []
for pred in oldpredicates:
    predicates.append(len(pred))

predicatesCounts_df = pd.DataFrame()
predicatesCounts_df["predicatesCounts"] = pd.DataFrame(predicates)
predicatesCounts_df = predicatesCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
predicatesCounts_df["Correct"] = output_dataset['Correct']
predicatesCounts_df

predicatesCounts = predicatesCounts_df.groupby(['Correct', 'predicatesCounts']).size()
predicatesCounts
# Out:
# Correct  predicatesCounts
# False    1                   156
#          2                   153
# True     1                   387
#          2                   304
# dtype: int64

# %%
dfp = predicatesCounts_df.pivot_table(index='predicatesCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %% [markdown]
# FIRST LEARNING: MORE PREDICATES IS HARDER!!

# %%
# - with a certain size of the world model?
wmCounts_df = pd.DataFrame()
wmCounts_df["WorldModelCounts"] = pd.DataFrame(wmTemp)
wmCounts_df = wmCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
wmCounts_df["Correct"] = output_dataset['Correct']
wmCounts_df
# Out:
#        WorldModelCounts  Correct
# 80000                14     True
# 80001                12     True
# 80002                 6     True
# 80003                 2    False
# 80004                14     True
# ...                 ...      ...
# 80995                16     True
# 80996                 6     True
# 80997                 4    False
# 80998                18     True
# 80999                 8    False
#
# [1000 rows x 2 columns]

# %%
wmCounts = wmCounts_df.groupby(['Correct', 'WorldModelCounts']).size()
wmCounts
# Out:
# Correct  WorldModelCounts
# False    1                    6
#          2                   26
#          3                   17
#          4                   28
#          5                   20
#          6                   32
#          7                   15
#          8                   38
#          9                   11
#          10                  44
#          12                  18
#          14                  14
#          16                   9
#          18                  15
#          20                  16
# True     1                   25
#          2                   37
#          3                   42
#          4                   52
#          5                   39
#          6                   77
#          7                   54
#          8                   74
#          9                   41
#          10                  64
#          12                  35
#          14                  41
#          16                  34
#          18                  42
#          20                  34
# dtype: int64

# %%
dfp = wmCounts_df.pivot_table(index='WorldModelCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %% [markdown]
# World model size does not seem to make a difference! -> but plot a regression or something.

# %%
# - with a certain number of operators? 
operatorCounts_df = pd.DataFrame()
operatorCounts_df["operatorCounts"] = pd.DataFrame(numTotalOperators)
operatorCounts_df = operatorCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
operatorCounts_df["Correct"] = output_dataset['Correct']
operatorCounts_df
# Out:
#        operatorCounts  Correct
# 80000               4     True
# 80001               5     True
# 80002               2     True
# 80003               3    False
# 80004               2     True
# ...               ...      ...
# 80995               4     True
# 80996               4     True
# 80997               5    False
# 80998               4     True
# 80999               5    False
#
# [1000 rows x 2 columns]

# %%
operatorCounts = operatorCounts_df.groupby(['Correct', 'operatorCounts']).size()
operatorCounts
# Out:
# Correct  operatorCounts
# False    0                   4
#          1                  17
#          2                  59
#          3                 102
#          4                  76
#          5                  39
#          6                  12
# True     0                  11
#          1                  43
#          2                 108
#          3                 194
#          4                 217
#          5                 102
#          6                  16
# dtype: int64

# %%
dfp = operatorCounts_df.pivot_table(index='operatorCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
# - with a certain type of operator? (negation, implication, and-operator) 
# negation
negationCounts_df = pd.DataFrame()
negationCounts_df["negationCounts"] = pd.DataFrame(numNegations)
negationCounts_df = negationCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
negationCounts_df["Correct"] = output_dataset['Correct']
negationCounts_df
# Out:
#        negationCounts  Correct
# 80000               3     True
# 80001               4     True
# 80002               1     True
# 80003               2    False
# 80004               1     True
# ...               ...      ...
# 80995               3     True
# 80996               3     True
# 80997               4    False
# 80998               3     True
# 80999               4    False
#
# [1000 rows x 2 columns]

# %%
negationCounts = negationCounts_df.groupby(['Correct', 'negationCounts']).size()
negationCounts
# Out:
# Correct  negationCounts
# False    0                  13
#          1                  63
#          2                 106
#          3                  76
#          4                  39
#          5                  12
# True     0                  32
#          1                 121
#          2                 203
#          3                 217
#          4                 102
#          5                  16
# dtype: int64

# %%
dfp = negationCounts_df.pivot_table(index='negationCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
# implication
implicationCounts_df = pd.DataFrame()
implicationCounts_df["implicationCounts"] = pd.DataFrame(numImplications)
implicationCounts_df = implicationCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
implicationCounts_df["Correct"] = output_dataset['Correct']
implicationCounts_df
# Out:
#        implicationCounts  Correct
# 80000                  1     True
# 80001                  1     True
# 80002                  0     True
# 80003                  0    False
# 80004                  0     True
# ...                  ...      ...
# 80995                  1     True
# 80996                  1     True
# 80997                  1    False
# 80998                  1     True
# 80999                  1    False
#
# [1000 rows x 2 columns]

# %%
implicationCounts = implicationCounts_df.groupby(['Correct', 'implicationCounts']).size()
implicationCounts
# Out:
# Correct  implicationCounts
# False    0                    166
#          1                    143
# True     0                    366
#          1                    325
# dtype: int64

# %%
dfp = implicationCounts_df.pivot_table(index='implicationCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
# and-operator
andOpCounts_df = pd.DataFrame()
andOpCounts_df["andOpCounts"] = pd.DataFrame(numAnds)
andOpCounts_df = andOpCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
andOpCounts_df["Correct"] = output_dataset['Correct']
andOpCounts_df
# Out:
#        andOpCounts  Correct
# 80000            0     True
# 80001            0     True
# 80002            1     True
# 80003            1    False
# 80004            1     True
# ...            ...      ...
# 80995            0     True
# 80996            0     True
# 80997            0    False
# 80998            0     True
# 80999            0    False
#
# [1000 rows x 2 columns]

# %%
andOpCounts = andOpCounts_df.groupby(['Correct', 'andOpCounts']).size()
andOpCounts
# Out:
# Correct  andOpCounts
# False    0              159
#          1              150
# True     0              367
#          1              324
# dtype: int64

# %%
dfp = andOpCounts_df.pivot_table(index='andOpCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
def get_frequencies(output_dataset, count_list, column_name):
    temp_df = pd.DataFrame()
    temp_df[column_name] = pd.DataFrame(count_list)
    temp_df = temp_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
    temp_df["Correct"] = output_dataset['Correct']
    return temp_df.groupby(['Correct', column_name]).size()

# %%
# -> especially: is there negation in front of quantifiers or not? 
get_frequencies(output_dataset, numNegationInFront, "NegationInFront")
# Out:
# Correct  NegationInFront
# False    False              161
#          True               148
# True     False              345
#          True               346
# dtype: int64

# %%
#  using only no operators vs. unary vs. binary operators // 
get_frequencies(output_dataset, unaryOperators, "UnaryOperator")
# Out:
# Correct  UnaryOperator
# False    False            297
#          True              12
# True     False            660
#          True              31
# dtype: int64

# %%
get_frequencies(output_dataset, binaryOperators, "BinaryOperator")
# Out:
# Correct  BinaryOperator
# False    False             296
#          True               13
# True     False             659
#          True               32
# dtype: int64

# %%
get_frequencies(output_dataset, unaryBinaryOperators, "UnaryAndBinaryOperators")
# Out:
# Correct  UnaryAndBinaryOperators
# False    False                       25
#          True                       284
# True     False                       63
#          True                       628
# dtype: int64

# %% [markdown]
# We need to look here at the relative frequencies: it tends to be about 5% ratio or 10% ratio. So quite balanced. i.e. no set of operators leads to a worse outcome. => Qualitative analysis necessary!

# %% [markdown]
# ### Tautologies / Contradictions

# %%
import nltk
from nltk.inference.prover9 import BaseProverCommand, Prover, Prover9Command
from nltk.sem import Expression
from nltk.sem.logic import (
    AllExpression,
    AndExpression,
    EqualityExpression,
    ExistsExpression,
    Expression,
    IffExpression,
    ImpExpression,
    NegatedExpression,
    OrExpression,
)
from nltk import *
from nltk.sem.drt import DrtParser
from nltk.sem import logic

# %%
# a formula without assumptions is generally false (instead of undefined) for ResolutionProver.
# Tested the functions below so that tautologies are recognised, contradictions as well, but not other formulas (which are neither contradictions or tautologies).

# %%
def is_tautology(expression):
    # needs to be true, regardless of the input.
    # needs to be false when negated, regardless of the input.
    if ResolutionProver().prove(expression, [], verbose=True) and not ResolutionProver().prove(NegatedExpression(expression), [], verbose=True):
        return True
    else:
        return False

# %%
def is_contradiction(expression):
    # needs to be false, regardless of the input.
    # needs to be true when negated, regardless of the input.
    if not ResolutionProver().prove(expression, [], verbose=True) and ResolutionProver().prove(NegatedExpression(expression), [], verbose=True):
        return True
    else:
        return False

# %%
read_expr = Expression.fromstring

# %%
formula = read_expr(base_dataset["Formula"].iloc[59])
formula = NegatedExpression(formula) # negating a contradiction makes it a tautology.
formula
# Out:
# <NegatedExpression -all x.(G(x) & -G(x))>

# %%
res = ResolutionProver().prove(formula, [], verbose=True)
# Out:
# [1] {G(z2)}   A
# [2] {-G(z3)}  A
# [3] {}        (1, 2)

# %% [markdown]
# Descriptive Statistics regarding tautologies

# %%
numTautologies = []
numContradictions = []
for i in range(len(base_dataset)):
    formula = base_dataset['Formula'].iloc[i]
    numTautologies.append(is_tautology(read_expr(formula)))
    numContradictions.append(is_contradiction(read_expr(formula)))
# Out:
# [1] {-F(z2), -G(z2)}  A
#
# [1] {-F(z4), -G(z4)}  A
#
# [1] {F(z6)}  A
# [2] {G(z7)}  A
#
# [1] {F(z9)}   A
# [2] {G(z10)}  A
#
# [1] {F(z12)}  A
# [2] {G(z13)}  A
#
# [1] {-F(z15), -G(z15)}  A
#
# [1] {-F(z17), G(z17)}  A
#
# [1] {-F(z19), G(z19)}  A
#
# [1] {F(z21)}   A
# [2] {-G(z22)}  A
#
# [1] {F(z24)}   A
# [2] {-G(z25)}  A
#
# [1] {F(z27)}   A
# [2] {-G(z28)}  A
#
# [1] {-F(z30), G(z30)}  A
#
# [1] {-F(z32), G(z32)}  A
#
# [1] {-F(z34), G(z34)}  A
#
# [1] {F(z36)}   A
# [2] {-G(z37)}  A
#
# [1] {F(z39)}   A
# [2] {-G(z40)}  A
#
# [1] {F(z42)}   A
# [2] {-G(z43)}  A
#
# [1] {-F(z45), G(z45)}  A
#
# [1] {F(z47)}   A
# [2] {-G(z48)}  A
#
# [1] {F(z50)}   A
# [2] {-G(z51)}  A
#
# [1] {-F(z53), G(z53)}  A
#
# [1] {-F(z55), G(z55)}  A
#
# [1] {-F(z57), G(z57)}  A
#
# [1] {F(z59)}   A
# [2] {-G(z60)}  A
#
# [1] {F(z62)}   A
# [2] {-G(z63)}  A
#
# [1] {F(z65)}   A
# [2] {-G(z66)}  A
#
# [1] {-F(z68), G(z68)}  A
#
# [1] {-F(z70), G(z70)}  A
#
# [1] {-F(z72), G(z72)}  A
#
# [1] {F(z74)}   A
# [2] {-G(z75)}  A
#
# [1] {G(z77)}   A
# [2] {-F(z78)}  A
#
# [1] {G(z80)}   A
# [2] {-F(z81)}  A
#
# [1] {-G(z83), F(z83)}  A
#
# [1] {G(z85)}   A
# [2] {-F(z86)}  A
#
# [1] {G(z88)}   A
# [2] {-F(z89)}  A
#
# [1] {-G(z91), F(z91)}  A
#
# [1] {-G(z93), F(z93)}  A
#
# [1] {-G(z95), F(z95)}  A
#
# [1] {G(z97)}   A
# [2] {-F(z98)}  A
#
# [1] {-G(z100), F(z100)}  A
#
# [1] {-G(z102), F(z102)}  A
#
# [1] {G(z104)}   A
# [2] {-F(z105)}  A
#
# [1] {G(z107)}   A
# [2] {-F(z108)}  A
#
# [1] {G(z110)}   A
# [2] {-F(z111)}  A
#
# [1] {-G(z113), F(z113)}  A
#
# [1] {-G(z115), F(z115)}  A
#
# [1] {-G(z117), F(z117)}  A
#
# [1] {G(z119)}   A
# [2] {-F(z120)}  A
#
# [1] {G(z122)}   A
# [2] {-F(z123)}  A
#
# [1] {G(z125)}   A
# [2] {-F(z126)}  A
#
# [1] {-G(z128), F(z128)}  A
#
# [1] {-G(z130), -F(z130)}  A
#
# [1] {-G(z132), -F(z132)}  A
#
# [1] {G(z134)}  A
# [2] {F(z135)}  A
#
# [1] {G(z137)}  A
# [2] {F(z138)}  A
#
# [1] {G(z140)}  A
# [2] {F(z141)}  A
#
# [1] {-G(z143), -F(z143)}  A
#
# [1] {-G(z145), -F(z145)}  A
#
# [1] {-G(z147), -F(z147)}  A
#
# [1] {G(z149)}  A
# [2] {F(z150)}  A
#
# [1] {G(z152)}  A
# [2] {F(z153)}  A
#
# [1] {G(z155)}  A
# [2] {F(z156)}  A
#
# [1] {-G(z158), -F(z158)}  A
#
# [1] {G(z160)}   A
# [2] {-G(z161)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z163), G(z163)}  A Tautology
#
# [1] {G(z165)}   A
# [2] {-G(z166)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z168), G(z168)}  A Tautology
#
# [1] {-G(z170), G(z170)}  A Tautology
#
# [1] {G(z172)}   A
# [2] {-G(z173)}  A
# [3] {}          (1, 2)
#
# [1] {G(z175)}   A
# [2] {-G(z176)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z178), G(z178)}  A Tautology
#
# [1] {G(z180)}   A
# [2] {-G(z181)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z183), G(z183)}  A Tautology
#
# [1] {-G(z185), G(z185)}  A Tautology
#
# [1] {G(z187)}   A
# [2] {-G(z188)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z190), G(z190)}  A Tautology
#
# [1] {-G(z192), G(z192)}  A Tautology
#
# [1] {G(z194)}   A
# [2] {-G(z195)}  A
# [3] {}          (1, 2)
#
# [1] {G(z197)}   A
# [2] {-G(z198)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z200), G(z200)}  A Tautology
#
# [1] {G(z202)}   A
# [2] {-G(z203)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z205), G(z205)}  A Tautology
#
# [1] {-G(z207), G(z207)}  A Tautology
#
# [1] {G(z209)}   A
# [2] {-G(z210)}  A
# [3] {}          (1, 2)
#
# [1] {G(z212)}   A
# [2] {-G(z213)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z215), G(z215)}  A Tautology
#
# [1] {G(z217)}   A
# [2] {-G(z218)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z220), -G(z220)}  A
#
# [1] {-G(z222), -G(z222)}  A
#
# [1] {G(z224)}  A
# [2] {G(z225)}  A
#
# [1] {G(z227)}  A
# [2] {G(z228)}  A
#
# [1] {G(z230)}  A
# [2] {G(z231)}  A
#
# [1] {-G(z233), -G(z233)}  A
#
# [1] {-G(z235), -G(z235)}  A
#
# [1] {-G(z237), -G(z237)}  A
#
# [1] {G(z239)}  A
# [2] {G(z240)}  A
#
# [1] {G(z242)}  A
# [2] {G(z243)}  A
#
# [1] {G(z245)}  A
# [2] {G(z246)}  A
#
# [1] {-G(z248), -G(z248)}  A
#
# [1] {G(z250)}  A
# [2] {G(z251)}  A
#
# [1] {G(z253)}  A
# [2] {G(z254)}  A
#
# [1] {-G(z256), -G(z256)}  A
#
# [1] {-G(z258), -G(z258)}  A
#
# [1] {-G(z260), -G(z260)}  A
#
# [1] {G(z262)}  A
# [2] {G(z263)}  A
#
# [1] {G(z265)}  A
# [2] {G(z266)}  A
#
# [1] {G(z268)}  A
# [2] {G(z269)}  A
#
# [1] {-G(z271), -G(z271)}  A
#
# [1] {-G(z273), -G(z273)}  A
#
# [1] {-G(z275), -G(z275)}  A
#
# [1] {G(z277)}  A
# [2] {G(z278)}  A
#
# [1] {G(z280)}  A
# [2] {F(z281)}  A
#
# [1] {G(z283)}  A
# [2] {F(z284)}  A
#
# [1] {-G(z286), -F(z286)}  A
#
# [1] {-G(z288), -F(z288)}  A
#
# [1] {-G(z290), -F(z290)}  A
#
# [1] {G(z292)}  A
# [2] {F(z293)}  A
#
# [1] {G(z295)}  A
# [2] {F(z296)}  A
#
# [1] {G(z298)}  A
# [2] {F(z299)}  A
#
# [1] {-G(z301), -F(z301)}  A
#
# [1] {-G(z303), -F(z303)}  A
#
# [1] {-G(z305), -F(z305)}  A
#
# [1] {G(z307)}  A
# [2] {F(z308)}  A
#
# [1] {-G(z310), -F(z310)}  A
#
# [1] {-G(z312), -F(z312)}  A
#
# [1] {G(z314)}  A
# [2] {F(z315)}  A
#
# [1] {G(z317)}  A
# [2] {F(z318)}  A
#
# [1] {G(z320)}  A
# [2] {F(z321)}  A
#
# [1] {-G(z323), -F(z323)}  A
#
# [1] {-G(z325), -F(z325)}  A
#
# [1] {-G(z327), -F(z327)}  A
#
# [1] {G(z329)}  A
# [2] {F(z330)}  A
#
# [1] {-G(z332), F(z332)}  A
#
# [1] {-G(z334), F(z334)}  A
#
# [1] {G(z336)}   A
# [2] {-F(z337)}  A
#
# [1] {G(z339)}   A
# [2] {-F(z340)}  A
#
# [1] {G(z342)}   A
# [2] {-F(z343)}  A
#
# [1] {-G(z345), F(z345)}  A
#
# [1] {-G(z347), F(z347)}  A
#
# [1] {-G(z349), F(z349)}  A
#
# [1] {G(z351)}   A
# [2] {-F(z352)}  A
#
# [1] {G(z354)}   A
# [2] {-F(z355)}  A
#
# [1] {G(z357)}   A
# [2] {-F(z358)}  A
#
# [1] {-G(z360), F(z360)}  A
#
# [1] {G(z362)}   A
# [2] {-F(z363)}  A
#
# [1] {G(z365)}   A
# [2] {-F(z366)}  A
#
# [1] {-G(z368), F(z368)}  A
#
# [1] {-G(z370), F(z370)}  A
#
# [1] {-G(z372), F(z372)}  A
#
# [1] {G(z374)}   A
# [2] {-F(z375)}  A
#
# [1] {G(z377)}   A
# [2] {-F(z378)}  A
#
# [1] {G(z380)}   A
# [2] {-F(z381)}  A
#
# [1] {-G(z383), F(z383)}  A
#
# [1] {-G(z385), F(z385)}  A
#
# [1] {-G(z387), F(z387)}  A
#
# [1] {G(z389)}   A
# [2] {-F(z390)}  A
#
# [1] {G(z392)}  A
# [2] {G(z393)}  A
#
# [1] {G(z395)}  A
# [2] {G(z396)}  A
#
# [1] {-G(z398), -G(z398)}  A
#
# [1] {-G(z400), -G(z400)}  A
#
# [1] {-G(z402), -G(z402)}  A
#
# [1] {G(z404)}  A
# [2] {G(z405)}  A
#
# [1] {G(z407)}  A
# [2] {G(z408)}  A
#
# [1] {G(z410)}  A
# [2] {G(z411)}  A
#
# [1] {-G(z413), -G(z413)}  A
#
# [1] {-G(z415), -G(z415)}  A
#
# [1] {-G(z417), -G(z417)}  A
#
# [1] {G(z419)}  A
# [2] {G(z420)}  A
#
# [1] {-G(z422), -G(z422)}  A
#
# [1] {-G(z424), -G(z424)}  A
#
# [1] {G(z426)}  A
# [2] {G(z427)}  A
#
# [1] {G(z429)}  A
# [2] {G(z430)}  A
#
# [1] {G(z432)}  A
# [2] {G(z433)}  A
#
# [1] {-G(z435), -G(z435)}  A
#
# [1] {G(z437)}  A
# [2] {G(z438)}  A
#
# [1] {G(z440)}  A
# [2] {G(z441)}  A
#
# [1] {-G(z443), -G(z443)}  A
#
# [1] {-G(z445), G(z445)}  A Tautology
#
# [1] {-G(z447), G(z447)}  A Tautology
#
# [1] {G(z449)}   A
# [2] {-G(z450)}  A
# [3] {}          (1, 2)
#
# [1] {G(z452)}   A
# [2] {-G(z453)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z455), G(z455)}  A Tautology
#
# [1] {G(z457)}   A
# [2] {-G(z458)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z460), G(z460)}  A Tautology
#
# [1] {-G(z462), G(z462)}  A Tautology
#
# [1] {G(z464)}   A
# [2] {-G(z465)}  A
# [3] {}          (1, 2)
#
# [1] {G(z467)}   A
# [2] {-G(z468)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z470), G(z470)}  A Tautology
#
# [1] {G(z472)}   A
# [2] {-G(z473)}  A
# [3] {}          (1, 2)
#
# [1] {G(z475)}   A
# [2] {-G(z476)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z478), G(z478)}  A Tautology
#
# [1] {G(z480)}   A
# [2] {-G(z481)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z483), G(z483)}  A Tautology
#
# [1] {-G(z485), G(z485)}  A Tautology
#
# [1] {G(z487)}   A
# [2] {-G(z488)}  A
# [3] {}          (1, 2)
#
# [1] {G(z490)}   A
# [2] {-G(z491)}  A
# [3] {}          (1, 2)
#
# [1] {-G(z493), G(z493)}  A Tautology
#
# [1] {G(z495)}   A
# [2] {-G(z496)}  A
# [3] {}          (1, 2)
#
# [1] {-F(z498)}  A
# [2] {-F(z499)}  A
#
# [1] {-F(z501)}  A
# [2] {-F(z502)}  A
#
# [1] {F(z504), F(z504)}  A
#
# [1] {F(z506), F(z506)}  A
#
# [1] {F(z508), F(z508)}  A
#
# [1] {-F(z510)}  A
# [2] {-F(z511)}  A
#
# [1] {-F(z513)}  A
# [2] {-F(z514)}  A
#
# [1] {-F(z516)}  A
# [2] {-F(z517)}  A
#
# [1] {F(z519), F(z519)}  A
#
# [1] {F(z521), F(z521)}  A
#
# [1] {F(z523), F(z523)}  A
#
# [1] {-F(z525)}  A
# [2] {-F(z526)}  A
#
# [1] {-F(z528)}  A
# [2] {-F(z529)}  A
#
# [1] {-F(z531)}  A
# [2] {-F(z532)}  A
#
# [1] {F(z534), F(z534)}  A
#
# [1] {F(z536), F(z536)}  A
#
# [1] {F(z538), F(z538)}  A
#
# [1] {-F(z540)}  A
# [2] {-F(z541)}  A
#
# [1] {-F(z543)}  A
# [2] {-F(z544)}  A
#
# [1] {-F(z546)}  A
# [2] {-F(z547)}  A
#
# [1] {F(z549), F(z549)}  A
#
# [1] {F(z551), -F(z551)}  A Tautology
#
# [1] {F(z553), -F(z553)}  A Tautology
#
# [1] {-F(z555)}  A
# [2] {F(z556)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z558)}  A
# [2] {F(z559)}   A
# [3] {}          (1, 2)
#
# [1] {F(z561), -F(z561)}  A Tautology
#
# [1] {-F(z563)}  A
# [2] {F(z564)}   A
# [3] {}          (1, 2)
#
# [1] {F(z566), -F(z566)}  A Tautology
#
# [1] {F(z568), -F(z568)}  A Tautology
#
# [1] {-F(z570)}  A
# [2] {F(z571)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z573)}  A
# [2] {F(z574)}   A
# [3] {}          (1, 2)
#
# [1] {F(z576), -F(z576)}  A Tautology
#
# [1] {-F(z578)}  A
# [2] {F(z579)}   A
# [3] {}          (1, 2)
#
# [1] {F(z581), -F(z581)}  A Tautology
#
# [1] {F(z583), -F(z583)}  A Tautology
#
# [1] {-F(z585)}  A
# [2] {F(z586)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z588)}  A
# [2] {F(z589)}   A
# [3] {}          (1, 2)
#
# [1] {F(z591), -F(z591)}  A Tautology
#
# [1] {-F(z593)}  A
# [2] {F(z594)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z596)}  A
# [2] {-G(z597)}  A
#
# [1] {-F(z599)}  A
# [2] {-G(z600)}  A
#
# [1] {F(z602), G(z602)}  A
#
# [1] {-F(z604)}  A
# [2] {-G(z605)}  A
#
# [1] {-F(z607)}  A
# [2] {-G(z608)}  A
#
# [1] {F(z610), G(z610)}  A
#
# [1] {F(z612), G(z612)}  A
#
# [1] {F(z614), G(z614)}  A
#
# [1] {-F(z616)}  A
# [2] {-G(z617)}  A
#
# [1] {-F(z619)}  A
# [2] {-G(z620)}  A
#
# [1] {-F(z622)}  A
# [2] {-G(z623)}  A
#
# [1] {F(z625), G(z625)}  A
#
# [1] {F(z627), G(z627)}  A
#
# [1] {F(z629), G(z629)}  A
#
# [1] {-F(z631)}  A
# [2] {-G(z632)}  A
#
# [1] {F(z634), -G(z634)}  A
#
# [1] {F(z636), -G(z636)}  A
#
# [1] {-F(z638)}  A
# [2] {G(z639)}   A
#
# [1] {-F(z641)}  A
# [2] {G(z642)}   A
#
# [1] {-F(z644)}  A
# [2] {G(z645)}   A
#
# [1] {F(z647), -G(z647)}  A
#
# [1] {-F(z649)}  A
# [2] {G(z650)}   A
#
# [1] {-F(z652)}  A
# [2] {G(z653)}   A
#
# [1] {F(z655), -G(z655)}  A
#
# [1] {F(z657), -G(z657)}  A
#
# [1] {F(z659), -G(z659)}  A
#
# [1] {-F(z661)}  A
# [2] {G(z662)}   A
#
# [1] {-F(z664)}  A
# [2] {G(z665)}   A
#
# [1] {-F(z667)}  A
# [2] {G(z668)}   A
#
# [1] {F(z670), -G(z670)}  A
#
# [1] {-F(z672)}  A
# [2] {F(z673)}   A
# [3] {}          (1, 2)
#
# [1] {F(z675), -F(z675)}  A Tautology
#
# [1] {-F(z677)}  A
# [2] {F(z678)}   A
# [3] {}          (1, 2)
#
# [1] {F(z680), -F(z680)}  A Tautology
#
# [1] {F(z682), -F(z682)}  A Tautology
#
# [1] {-F(z684)}  A
# [2] {F(z685)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z687)}  A
# [2] {F(z688)}   A
# [3] {}          (1, 2)
#
# [1] {F(z690), -F(z690)}  A Tautology
#
# [1] {-F(z692)}  A
# [2] {F(z693)}   A
# [3] {}          (1, 2)
#
# [1] {F(z695), -F(z695)}  A Tautology
#
# [1] {F(z697), -F(z697)}  A Tautology
#
# [1] {-F(z699)}  A
# [2] {F(z700)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z702)}  A
# [2] {F(z703)}   A
# [3] {}          (1, 2)
#
# [1] {F(z705), -F(z705)}  A Tautology
#
# [1] {-F(z707)}  A
# [2] {F(z708)}   A
# [3] {}          (1, 2)
#
# [1] {F(z710), -F(z710)}  A Tautology
#
# [1] {F(z712), -F(z712)}  A Tautology
#
# [1] {-F(z714)}  A
# [2] {F(z715)}   A
# [3] {}          (1, 2)
#
# [1] {-F(z717)}  A
# [2] {F(z718)}   A
# [3] {}          (1, 2)
#
# [1] {F(z720), -F(z720)}  A Tautology
#
# [1] {-F(z722)}  A
# [2] {F(z723)}   A
# [3] {}          (1, 2)
#
# [1] {F(z725), F(z725)}  A
#
# [1] {F(z727), F(z727)}  A
#
# [1] {-F(z729)}  A
# [2] {-F(z730)}  A
#
# [1] {-F(z732)}  A
# [2] {-F(z733)}  A
#
# [1] {-F(z735)}  A
# [2] {-F(z736)}  A
#
# [1] {F(z738), F(z738)}  A
#
# [1] {-F(z740)}  A
# [2] {-F(z741)}  A
#
# [1] {-F(z743)}  A
# [2] {-F(z744)}  A
#
# [1] {F(z746), F(z746)}  A
#
# [1] {-F(z748)}  A
# [2] {-F(z749)}  A
#
# [1] {-F(z751)}  A
# [2] {-F(z752)}  A
#
# [1] {F(z754), F(z754)}  A
#
# [1] {F(z756), F(z756)}  A
#
# [1] {F(z758), F(z758)}  A
#
# [1] {-F(z760)}  A
# [2] {-F(z761)}  A
#
# [1] {-F(z763)}  A
# [2] {-F(z764)}  A
#
# [1] {-F(z766)}  A
# [2] {-F(z767)}  A
#
# [1] {F(z769), F(z769)}  A
#
# [1] {F(z771), F(z771)}  A
#
# [1] {F(z773), F(z773)}  A
#
# [1] {-F(z775)}  A
# [2] {-F(z776)}  A
#
# [1] {-F(z778)}  A
# [2] {G(z779)}   A
#
# [1] {-F(z781)}  A
# [2] {G(z782)}   A
#
# [1] {F(z784), -G(z784)}  A
#
# [1] {F(z786), -G(z786)}  A
#
# [1] {F(z788), -G(z788)}  A
#
# [1] {-F(z790)}  A
# [2] {G(z791)}   A
#
# [1] {-F(z793)}  A
# [2] {G(z794)}   A
#
# [1] {-F(z796)}  A
# [2] {G(z797)}   A
#
# [1] {F(z799), -G(z799)}  A
#
# [1] {F(z801), -G(z801)}  A
#
# [1] {F(z803), -G(z803)}  A
#
# [1] {-F(z805)}  A
# [2] {G(z806)}   A
#
# [1] {F(z808), -G(z808)}  A
#
# [1] {F(z810), -G(z810)}  A
#
# [1] {-F(z812)}  A
# [2] {G(z813)}   A
#
# [1] {-F(z815)}  A
# [2] {G(z816)}   A
#
# [1] {-F(z818)}  A
# [2] {G(z819)}   A
#
# [1] {F(z821), -G(z821)}  A
#
# [1] {F(z823), -G(z823)}  A
#
# [1] {F(z825), -G(z825)}  A
#
# [1] {-F(z827)}  A
# [2] {G(z828)}   A
#
# [1] {-F(z830)}  A
# [2] {G(z831)}   A
#
# [1] {-F(z833)}  A
# [2] {G(z834)}   A
#
# [1] {F(z836), -G(z836)}  A
#
# [1] {F(z838), G(z838)}  A
#
# [1] {F(z840), G(z840)}  A
#
# [1] {-F(z842)}  A
# [2] {-G(z843)}  A
#
# [1] {-F(z845)}  A
# [2] {-G(z846)}  A
#
# [1] {-F(z848)}  A
# [2] {-G(z849)}  A
#
# [1] {F(z851), G(z851)}  A
#
# [1] {F(z853), G(z853)}  A
#
# [1] {F(z855), G(z855)}  A
#
# [1] {-F(z857)}  A
# [2] {-G(z858)}  A
#
# [1] {-F(z860)}  A
# [2] {-G(z861)}  A
#
# [1] {-F(z863)}  A
# [2] {-G(z864)}  A
#
# [1] {F(z866), G(z866)}  A
#
# [1] {-F(z868)}  A
# [2] {-G(z869)}  A
#
# [1] {-F(z871)}  A
# [2] {-G(z872)}  A
#
# [1] {F(z874), G(z874)}  A
#
# [1] {F(z876), G(z876)}  A
#
# [1] {F(z878), G(z878)}  A
#
# [1] {-F(z880)}  A
# [2] {-G(z881)}  A
#
# [1] {-F(z883)}  A
# [2] {-G(z884)}  A
#
# [1] {-F(z886)}  A
# [2] {-G(z887)}  A
#
# [1] {F(z889), G(z889)}  A
#
# [1] {-G(z891)}  A
# [2] {-F(z892)}  A
#
# [1] {-G(z894)}  A
# [2] {-F(z895)}  A
#
# [1] {G(z897), F(z897)}  A
#
# [1] {G(z899), F(z899)}  A
#
# [1] {G(z901), F(z901)}  A
#
# [1] {-G(z903)}  A
# [2] {-F(z904)}  A
#
# [1] {-G(z906)}  A
# [2] {-F(z907)}  A
#
# [1] {-G(z909)}  A
# [2] {-F(z910)}  A
#
# [1] {G(z912), F(z912)}  A
#
# [1] {G(z914), F(z914)}  A
#
# [1] {G(z916), F(z916)}  A
#
# [1] {-G(z918)}  A
# [2] {-F(z919)}  A
#
# [1] {-G(z921)}  A
# [2] {-F(z922)}  A
#
# [1] {-G(z924)}  A
# [2] {-F(z925)}  A
#
# [1] {G(z927), F(z927)}  A
#
# [1] {G(z929), F(z929)}  A
#
# [1] {G(z931), F(z931)}  A
#
# [1] {-G(z933)}  A
# [2] {-F(z934)}  A
#
# [1] {-G(z936)}  A
# [2] {-F(z937)}  A
#
# [1] {-G(z939)}  A
# [2] {-F(z940)}  A
#
# [1] {G(z942), F(z942)}  A
#
# [1] {G(z944), -F(z944)}  A
#
# [1] {G(z946), -F(z946)}  A
#
# [1] {-G(z948)}  A
# [2] {F(z949)}   A
#
# [1] {-G(z951)}  A
# [2] {F(z952)}   A
#
# [1] {-G(z954)}  A
# [2] {F(z955)}   A
#
# [1] {G(z957), -F(z957)}  A
#
# [1] {G(z959), -F(z959)}  A
#
# [1] {G(z961), -F(z961)}  A
#
# [1] {-G(z963)}  A
# [2] {F(z964)}   A
#
# [1] {-G(z966)}  A
# [2] {F(z967)}   A
#
# [1] {-G(z969)}  A
# [2] {F(z970)}   A
#
# [1] {G(z972), -F(z972)}  A
#
# [1] {-G(z974)}  A
# [2] {F(z975)}   A
#
# [1] {-G(z977)}  A
# [2] {F(z978)}   A
#
# [1] {G(z980), -F(z980)}  A
#
# [1] {G(z982), -F(z982)}  A
#
# [1] {G(z984), -F(z984)}  A
#
# [1] {-G(z986)}  A
# [2] {F(z987)}   A
#
# [1] {-G(z989)}  A
# [2] {F(z990)}   A
#
# [1] {-G(z992)}  A
# [2] {F(z993)}   A
#
# [1] {G(z995), -F(z995)}  A
#
# [1] {G(z997), -F(z997)}  A
#
# [1] {G(z999), -F(z999)}  A
#
# [1] {-G(z1001)}  A
# [2] {F(z1002)}   A
#
# [1] {-G(z1004)}  A
# [2] {-G(z1005)}  A
#
# [1] {-G(z1007)}  A
# [2] {-G(z1008)}  A
#
# [1] {G(z1010), G(z1010)}  A
#
# [1] {G(z1012), G(z1012)}  A
#
# [1] {G(z1014), G(z1014)}  A
#
# [1] {-G(z1016)}  A
# [2] {-G(z1017)}  A
#
# [1] {-G(z1019)}  A
# [2] {-G(z1020)}  A
#
# [1] {-G(z1022)}  A
# [2] {-G(z1023)}  A
#
# [1] {G(z1025), G(z1025)}  A
#
# [1] {G(z1027), G(z1027)}  A
#
# [1] {G(z1029), G(z1029)}  A
#
# [1] {-G(z1031)}  A
# [2] {-G(z1032)}  A
#
# [1] {G(z1034), G(z1034)}  A
#
# [1] {G(z1036), G(z1036)}  A
#
# [1] {-G(z1038)}  A
# [2] {-G(z1039)}  A
#
# [1] {G(z1041), G(z1041)}  A
#
# [1] {G(z1043), G(z1043)}  A
#
# [1] {-G(z1045)}  A
# [2] {-G(z1046)}  A
#
# [1] {G(z1048), -G(z1048)}  A Tautology
#
# [1] {G(z1050), -G(z1050)}  A Tautology
#
# [1] {-G(z1052)}  A
# [2] {G(z1053)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z1055)}  A
# [2] {G(z1056)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1058), -G(z1058)}  A Tautology
#
# [1] {-G(z1060)}  A
# [2] {G(z1061)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1063), -G(z1063)}  A Tautology
#
# [1] {G(z1065), -G(z1065)}  A Tautology
#
# [1] {-G(z1067)}  A
# [2] {G(z1068)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z1070)}  A
# [2] {G(z1071)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1073), -G(z1073)}  A Tautology
#
# [1] {-G(z1075)}  A
# [2] {G(z1076)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z1078)}  A
# [2] {G(z1079)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1081), -G(z1081)}  A Tautology
#
# [1] {-G(z1083)}  A
# [2] {G(z1084)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1086), -G(z1086)}  A Tautology
#
# [1] {G(z1088), -G(z1088)}  A Tautology
#
# [1] {-G(z1090)}  A
# [2] {G(z1091)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z1093)}  A
# [2] {G(z1094)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1096), -G(z1096)}  A Tautology
#
# [1] {-G(z1098)}  A
# [2] {G(z1099)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1101), -G(z1101)}  A Tautology
#
# [1] {G(z1103), -G(z1103)}  A Tautology
#
# [1] {-G(z1105)}  A
# [2] {G(z1106)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z1108)}  A
# [2] {F(z1109)}   A
#
# [1] {-G(z1111)}  A
# [2] {F(z1112)}   A
#
# [1] {G(z1114), -F(z1114)}  A
#
# [1] {-G(z1116)}  A
# [2] {F(z1117)}   A
#
# [1] {-G(z1119)}  A
# [2] {F(z1120)}   A
#
# [1] {G(z1122), -F(z1122)}  A
#
# [1] {G(z1124), -F(z1124)}  A
#
# [1] {G(z1126), -F(z1126)}  A
#
# [1] {-G(z1128)}  A
# [2] {F(z1129)}   A
#
# [1] {G(z1131), -F(z1131)}  A
#
# [1] {G(z1133), -F(z1133)}  A
#
# [1] {-G(z1135)}  A
# [2] {F(z1136)}   A
#
# [1] {G(z1138), -F(z1138)}  A
#
# [1] {G(z1140), -F(z1140)}  A
#
# [1] {-G(z1142)}  A
# [2] {F(z1143)}   A
#
# [1] {-G(z1145)}  A
# [2] {F(z1146)}   A
#
# [1] {-G(z1148)}  A
# [2] {F(z1149)}   A
#
# [1] {G(z1151), -F(z1151)}  A
#
# [1] {G(z1153), F(z1153)}  A
#
# [1] {G(z1155), F(z1155)}  A
#
# [1] {-G(z1157)}  A
# [2] {-F(z1158)}  A
#
# [1] {-G(z1160)}  A
# [2] {-F(z1161)}  A
#
# [1] {-G(z1163)}  A
# [2] {-F(z1164)}  A
#
# [1] {G(z1166), F(z1166)}  A
#
# [1] {G(z1168), F(z1168)}  A
#
# [1] {G(z1170), F(z1170)}  A
#
# [1] {-G(z1172)}  A
# [2] {-F(z1173)}  A
#
# [1] {-G(z1175)}  A
# [2] {-F(z1176)}  A
#
# [1] {-G(z1178)}  A
# [2] {-F(z1179)}  A
#
# [1] {G(z1181), F(z1181)}  A
#
# [1] {-G(z1183)}  A
# [2] {-F(z1184)}  A
#
# [1] {-G(z1186)}  A
# [2] {-F(z1187)}  A
#
# [1] {G(z1189), F(z1189)}  A
#
# [1] {G(z1191), F(z1191)}  A
#
# [1] {G(z1193), F(z1193)}  A
#
# [1] {-G(z1195)}  A
# [2] {-F(z1196)}  A
#
# [1] {-G(z1198)}  A
# [2] {-F(z1199)}  A
#
# [1] {-G(z1201)}  A
# [2] {-F(z1202)}  A
#
# [1] {G(z1204), F(z1204)}  A
#
# [1] {G(z1206), F(z1206)}  A
#
# [1] {G(z1208), F(z1208)}  A
#
# [1] {-G(z1210)}  A
# [2] {-F(z1211)}  A
#
# [1] {-G(z1213)}  A
# [2] {G(z1214)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1216), -G(z1216)}  A Tautology
#
# [1] {-G(z1218)}  A
# [2] {G(z1219)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1221), -G(z1221)}  A Tautology
#
# [1] {G(z1223), -G(z1223)}  A Tautology
#
# [1] {-G(z1225)}  A
# [2] {G(z1226)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z1228)}  A
# [2] {G(z1229)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1231), -G(z1231)}  A Tautology
#
# [1] {-G(z1233)}  A
# [2] {G(z1234)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1236), -G(z1236)}  A Tautology
#
# [1] {G(z1238), -G(z1238)}  A Tautology
#
# [1] {-G(z1240)}  A
# [2] {G(z1241)}   A
# [3] {}           (1, 2)
#
# [1] {-G(z1243)}  A
# [2] {G(z1244)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1246), -G(z1246)}  A Tautology
#
# [1] {-G(z1248)}  A
# [2] {G(z1249)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1251), -G(z1251)}  A Tautology
#
# [1] {G(z1253), -G(z1253)}  A Tautology
#
# [1] {-G(z1255)}  A
# [2] {G(z1256)}   A
# [3] {}           (1, 2)
#
# [1] {G(z1258), G(z1258)}  A
#
# [1] {G(z1260), G(z1260)}  A
#
# [1] {-G(z1262)}  A
# [2] {-G(z1263)}  A
#
# [1] {-G(z1265)}  A
# [2] {-G(z1266)}  A
#
# [1] {-G(z1268)}  A
# [2] {-G(z1269)}  A
#
# [1] {G(z1271), G(z1271)}  A
#
# [1] {G(z1273), G(z1273)}  A
#
# [1] {G(z1275), G(z1275)}  A
#
# [1] {-G(z1277)}  A
# [2] {-G(z1278)}  A
#
# [1] {-G(z1280)}  A
# [2] {-G(z1281)}  A
#
# [1] {-G(z1283)}  A
# [2] {-G(z1284)}  A
#
# [1] {G(z1286), G(z1286)}  A
#
# [1] {-G(z1288)}  A
# [2] {-G(z1289)}  A
#
# [1] {-G(z1291)}  A
# [2] {-G(z1292)}  A
#
# [1] {G(z1294), G(z1294)}  A
#
# [1] {G(z1296), G(z1296)}  A
#
# [1] {G(z1298), G(z1298)}  A
#
# [1] {-G(z1300)}  A
# [2] {-G(z1301)}  A
#
# [1] {-G(z1303)}  A
# [2] {-G(z1304)}  A
#
# [1] {-G(z1306)}  A
# [2] {-G(z1307)}  A
#
# [1] {G(z1309), G(z1309)}  A
#
# [1] {G(z1311), G(z1311)}  A
#
# [1] {G(z1313), G(z1313)}  A
#
# [1] {-G(z1315)}  A
# [2] {-G(z1316)}  A
#
# [1] {-F(z1318)}  A
#
# [1] {-F(z1320)}  A
#
# [1] {F(z1322)}  A
#
# [1] {F(z1324)}  A
#
# [1] {F(z1326)}  A
#
# [1] {-F(z1328)}  A
#
# [1] {-F(z1330)}  A
#
# [1] {-F(z1332)}  A
#
# [1] {F(z1334)}  A
#
# [1] {F(z1336)}  A
#
# [1] {F(z1338)}  A
#
# [1] {-F(z1340)}  A
#
# [1] {-G(z1342)}  A
#
# [1] {-G(z1344)}  A
#
# [1] {G(z1346)}  A
#
# [1] {G(z1348)}  A
#
# [1] {G(z1350)}  A
#
# [1] {-G(z1352)}  A
#
# [1] {-G(z1354)}  A
#
# [1] {-G(z1356)}  A
#
# [1] {G(z1358)}  A
#
# [1] {G(z1360)}  A
#
# [1] {G(z1362)}  A
#
# [1] {-G(z1364)}  A
#
# [1] {F(z1366)}  A
#
# [1] {F(z1368)}  A
#
# [1] {-F(z1370)}  A
#
# [1] {-F(z1372)}  A
#
# [1] {-F(z1374)}  A
#
# [1] {F(z1376)}  A
#
# [1] {F(z1378)}  A
#
# [1] {F(z1380)}  A
#
# [1] {-F(z1382)}  A
#
# [1] {-F(z1384)}  A
#
# [1] {-F(z1386)}  A
#
# [1] {F(z1388)}  A
#
# [1] {G(z1390)}  A
#
# [1] {G(z1392)}  A
#
# [1] {-G(z1394)}  A
#
# [1] {-G(z1396)}  A
#
# [1] {-G(z1398)}  A
#
# [1] {G(z1400)}  A
#
# [1] {G(z1402)}  A
#
# [1] {G(z1404)}  A
#
# [1] {-G(z1406)}  A
#
# [1] {-G(z1408)}  A
#
# [1] {-G(z1410)}  A
#
# [1] {G(z1412)}  A
#
# [1] {F(z1414)}   A
# [2] {-F(z1415)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1417), F(z1417)}  A Tautology
#
# [1] {F(z1419)}   A
# [2] {-F(z1420)}  A
# [3] {}           (1, 2)
#
# [1] {F(z1422)}   A
# [2] {-F(z1423)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1425), F(z1425)}  A Tautology
#
# [1] {F(z1427)}   A
# [2] {-F(z1428)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1430), F(z1430)}  A Tautology
#
# [1] {-F(z1432), F(z1432)}  A Tautology
#
# [1] {F(z1434)}   A
# [2] {-F(z1435)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1437), F(z1437)}  A Tautology
#
# [1] {-F(z1439), F(z1439)}  A Tautology
#
# [1] {F(z1441)}   A
# [2] {-F(z1442)}  A
# [3] {}           (1, 2)
#
# [1] {F(z1444)}   A
# [2] {-F(z1445)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1447), F(z1447)}  A Tautology
#
# [1] {F(z1449)}   A
# [2] {-F(z1450)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1452), F(z1452)}  A Tautology
#
# [1] {-F(z1454), F(z1454)}  A Tautology
#
# [1] {F(z1456)}   A
# [2] {-F(z1457)}  A
# [3] {}           (1, 2)
#
# [1] {-F(z1459), -F(z1459)}  A
#
# [1] {-F(z1461), -F(z1461)}  A
#
# [1] {F(z1463)}  A
# [2] {F(z1464)}  A
#
# [1] {F(z1466)}  A
# [2] {F(z1467)}  A
#
# [1] {F(z1469)}  A
# [2] {F(z1470)}  A
#
# [1] {-F(z1472), -F(z1472)}  A
#
# [1] {-F(z1474), -F(z1474)}  A
#
# [1] {-F(z1476), -F(z1476)}  A
#
# [1] {F(z1478)}  A
# [2] {F(z1479)}  A
#
# [1] {F(z1481)}  A
# [2] {F(z1482)}  A
#
# [1] {F(z1484)}  A
# [2] {F(z1485)}  A
#
# [1] {-F(z1487), -F(z1487)}  A
#
# [1] {F(z1489)}  A
# [2] {F(z1490)}  A
#
# [1] {F(z1492)}  A
# [2] {F(z1493)}  A
#
# [1] {-F(z1495), -F(z1495)}  A
#
# [1] {-F(z1497), -F(z1497)}  A
#
# [1] {-F(z1499), -F(z1499)}  A
#
# [1] {F(z1501)}  A
# [2] {F(z1502)}  A
#
# [1] {F(z1504)}  A
# [2] {F(z1505)}  A
#
# [1] {F(z1507)}  A
# [2] {F(z1508)}  A
#
# [1] {-F(z1510), -F(z1510)}  A
#
# [1] {-F(z1512), -F(z1512)}  A
#
# [1] {-F(z1514), -F(z1514)}  A
#
# [1] {F(z1516)}  A
# [2] {F(z1517)}  A
#
# [1] {F(z1519)}   A
# [2] {-G(z1520)}  A
#
# [1] {F(z1522)}   A
# [2] {-G(z1523)}  A
#
# [1] {-F(z1525), G(z1525)}  A
#
# [1] {-F(z1527), G(z1527)}  A
#
# [1] {-F(z1529), G(z1529)}  A
#
# [1] {F(z1531)}   A
# [2] {-G(z1532)}  A
#
# [1] {F(z1534)}   A
# [2] {-G(z1535)}  A
#
# [1] {F(z1537)}   A
# [2] {-G(z1538)}  A
#
# [1] {-F(z1540), G(z1540)}  A
#
# [1] {-F(z1542), G(z1542)}  A
#
# [1] {-F(z1544), G(z1544)}  A
#
# [1] {F(z1546)}   A
# [2] {-G(z1547)}  A
#
# [1] {-F(z1549), G(z1549)}  A
#
# [1] {-F(z1551), G(z1551)}  A
#
# [1] {F(z1553)}   A
# [2] {-G(z1554)}  A
#
# [1] {F(z1556)}   A
# [2] {-G(z1557)}  A
#
# [1] {F(z1559)}   A
# [2] {-G(z1560)}  A
#
# [1] {-F(z1562), G(z1562)}  A
#
# [1] {-F(z1564), G(z1564)}  A
#
# [1] {-F(z1566), G(z1566)}  A
#
# [1] {F(z1568)}   A
# [2] {-G(z1569)}  A
#
# [1] {F(z1571)}   A
# [2] {-G(z1572)}  A
#
# [1] {F(z1574)}   A
# [2] {-G(z1575)}  A
#
# [1] {-F(z1577), G(z1577)}  A
#
# [1] {-F(z1579), -G(z1579)}  A
#
# [1] {-F(z1581), -G(z1581)}  A
#
# [1] {F(z1583)}  A
# [2] {G(z1584)}  A
#
# [1] {F(z1586)}  A
# [2] {G(z1587)}  A
#
# [1] {F(z1589)}  A
# [2] {G(z1590)}  A
#
# [1] {-F(z1592), -G(z1592)}  A
#
# [1] {-F(z1594), -G(z1594)}  A
#
# [1] {-F(z1596), -G(z1596)}  A
#
# [1] {F(z1598)}  A
# [2] {G(z1599)}  A
#
# [1] {F(z1601)}  A
# [2] {G(z1602)}  A
#
# [1] {F(z1604)}  A
# [2] {G(z1605)}  A
#
# [1] {-F(z1607), -G(z1607)}  A
#
# [1] {F(z1609)}  A
# [2] {G(z1610)}  A
#
# [1] {F(z1612)}  A
# [2] {G(z1613)}  A
#
# [1] {-F(z1615), -G(z1615)}  A
#
# [1] {-F(z1617), -G(z1617)}  A
#
# [1] {-F(z1619), -G(z1619)}  A
#
# [1] {F(z1621)}  A
# [2] {G(z1622)}  A
#
# [1] {F(z1624)}  A
# [2] {G(z1625)}  A
#
# [1] {F(z1627)}  A
# [2] {G(z1774)}  A
#
# [1] {F(z1776)}  A
# [2] {G(z1777)}  A
#
# [1] {-F(z1779), -G(z1779)}  A
#
# [1] {-F(z1781), -G(z1781)}  A
#
# [1] {-F(z1783), -G(z1783)}  A
#
# [1] {F(z1785)}  A
# [2] {G(z1786)}  A
#
# [1] {F(z1788)}  A
# [2] {G(z1789)}  A
#
# [1] {F(z1791)}  A
# [2] {G(z1792)}  A
#
# [1] {-F(z1794), -G(z1794)}  A
#
# [1] {-F(z1796), G(z1796)}  A
#
# [1] {-F(z1798), G(z1798)}  A
#
# [1] {F(z1800)}   A
# [2] {-G(z1801)}  A
#
# [1] {F(z1803)}   A
# [2] {-G(z1804)}  A
#
# [1] {F(z1806)}   A
# [2] {-G(z1807)}  A
#
# [1] {-F(z1809), G(z1809)}  A
#
# [1] {-F(z1811), G(z1811)}  A
#
# [1] {-F(z1813), G(z1813)}  A
#
# [1] {F(z1815)}   A
# [2] {-G(z1816)}  A
#
# [1] {F(z1818)}   A
# [2] {-G(z1819)}  A
#
# [1] {F(z1821)}   A
# [2] {-G(z1822)}  A
#
# [1] {-F(z1824), G(z1824)}  A
#
# [1] {F(z1826)}   A
# [2] {-G(z1827)}  A
#
# [1] {F(z1829)}   A
# [2] {-G(z1830)}  A
#
# [1] {-F(z1832), G(z1832)}  A
#
# [1] {-F(z1834), G(z1834)}  A
#
# [1] {-F(z1836), G(z1836)}  A
#
# [1] {F(z1838)}   A
# [2] {-G(z1839)}  A
#
# [1] {F(z1841)}   A
# [2] {-G(z1842)}  A
#
# [1] {F(z1844)}   A
# [2] {-G(z1845)}  A
#
# [1] {-F(z1847), G(z1847)}  A
#
# [1] {-F(z1849), G(z1849)}  A
#
# [1] {-F(z1851), G(z1851)}  A
#
# [1] {F(z1853)}   A
# [2] {-G(z1854)}  A
#
# [1] {-G(z1856), F(z1856)}  A
#
# [1] {-G(z1858), F(z1858)}  A
#
# [1] {G(z1860)}   A
# [2] {-F(z1861)}  A
#
# [1] {G(z1863)}   A
# [2] {-F(z1864)}  A
#
# [1] {G(z1866)}   A
# [2] {-F(z1867)}  A
#
# [1] {-G(z1869), F(z1869)}  A
#
# [1] {-G(z1871), F(z1871)}  A
#
# [1] {-G(z1873), F(z1873)}  A
#
# [1] {G(z1875)}   A
# [2] {-F(z1876)}  A
#
# [1] {-G(z1878), F(z1878)}  A
#
# [1] {-G(z1880), F(z1880)}  A
#
# [1] {G(z1882)}   A
# [2] {-F(z1883)}  A
#
# [1] {-G(z1885), F(z1885)}  A
#
# [1] {-G(z1887), F(z1887)}  A
#
# [1] {G(z1889)}   A
# [2] {-F(z1890)}  A
#
# [1] {G(z1892)}   A
# [2] {-F(z1893)}  A
#
# [1] {G(z1895)}   A
# [2] {-F(z1896)}  A
#
# [1] {-G(z1898), F(z1898)}  A
#
# [1] {-G(z1900), -F(z1900)}  A
#
# [1] {-G(z1902), -F(z1902)}  A
#
# [1] {G(z1904)}  A
# [2] {F(z1905)}  A
#
# [1] {G(z1907)}  A
# [2] {F(z1908)}  A
#
# [1] {G(z1910)}  A
# [2] {F(z1911)}  A
#
# [1] {-G(z1913), -F(z1913)}  A
#
# [1] {-G(z1915), -F(z1915)}  A
#
# [1] {-G(z1917), -F(z1917)}  A
#
# [1] {G(z1919)}  A
# [2] {F(z1920)}  A
#
# [1] {G(z1922)}  A
# [2] {F(z1923)}  A
#
# [1] {G(z1925)}  A
# [2] {F(z1926)}  A
#
# [1] {-G(z1928), -F(z1928)}  A
#
# [1] {G(z1930)}  A
# [2] {F(z1931)}  A
#
# [1] {G(z1933)}  A
# [2] {F(z1934)}  A
#
# [1] {-G(z1936), -F(z1936)}  A
#
# [1] {G(z1938)}   A
# [2] {-G(z1939)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1941), G(z1941)}  A Tautology
#
# [1] {G(z1943)}   A
# [2] {-G(z1944)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1946), G(z1946)}  A Tautology
#
# [1] {-G(z1948), G(z1948)}  A Tautology
#
# [1] {G(z1950)}   A
# [2] {-G(z1951)}  A
# [3] {}           (1, 2)
#
# [1] {G(z1953)}   A
# [2] {-G(z1954)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1956), G(z1956)}  A Tautology
#
# [1] {G(z1958)}   A
# [2] {-G(z1959)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1961), G(z1961)}  A Tautology
#
# [1] {-G(z1963), G(z1963)}  A Tautology
#
# [1] {G(z1965)}   A
# [2] {-G(z1966)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1968), G(z1968)}  A Tautology
#
# [1] {-G(z1970), G(z1970)}  A Tautology
#
# [1] {G(z1972)}   A
# [2] {-G(z1973)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1975), G(z1975)}  A Tautology
#
# [1] {-G(z1977), G(z1977)}  A Tautology
#
# [1] {G(z1979)}   A
# [2] {-G(z1980)}  A
# [3] {}           (1, 2)
#
# [1] {G(z1982)}   A
# [2] {-G(z1983)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1985), G(z1985)}  A Tautology
#
# [1] {G(z1987)}   A
# [2] {-G(z1988)}  A
# [3] {}           (1, 2)
#
# [1] {-G(z1990), -G(z1990)}  A
#
# [1] {-G(z1992), -G(z1992)}  A
#
# [1] {G(z1994)}  A
# [2] {G(z1995)}  A
#
# [1] {G(z1997)}  A
# [2] {G(z1998)}  A
#
# [1] {G(z2000)}  A
# [2] {G(z2001)}  A
#
# [1] {-G(z2003), -G(z2003)}  A
#
# [1] {G(z2005)}  A
# [2] {G(z2006)}  A
#
# [1] {G(z2008)}  A
# [2] {G(z2009)}  A
#
# [1] {-G(z2011), -G(z2011)}  A
#
# [1] {G(z2013)}  A
# [2] {G(z2014)}  A
#
# [1] {G(z2016)}  A
# [2] {G(z2017)}  A
#
# [1] {-G(z2019), -G(z2019)}  A
#
# [1] {-G(z2021), -G(z2021)}  A
#
# [1] {-G(z2023), -G(z2023)}  A
#
# [1] {G(z2025)}  A
# [2] {G(z2026)}  A
#
# [1] {G(z2028)}  A
# [2] {G(z2029)}  A
#
# [1] {G(z2031)}  A
# [2] {G(z2032)}  A
#
# [1] {-G(z2034), -G(z2034)}  A
#
# [1] {-G(z2036), -G(z2036)}  A
#
# [1] {-G(z2038), -G(z2038)}  A
#
# [1] {G(z2040)}  A
# [2] {G(z2041)}  A
#
# [1] {-G(z2043), -F(z2043)}  A
#
# [1] {-G(z2045), -F(z2045)}  A
#
# [1] {G(z2047)}  A
#
# [1] {G(z7363)}  A
# [2] {G(z7364)}  A
#
# [1] {G(z7366)}  A
# [2] {F(z7367)}  A
#
# [1] {G(z7369)}  A
# [2] {F(z7370)}  A
#
# [1] {-G(z7372), -F(z7372)}  A
#
# [1] {-G(z7374), -F(z7374)}  A
#
# [1] {-G(z7376), -F(z7376)}  A
#
# [1] {G(z7378)}  A
# [2] {F(z7379)}  A
#
# [1] {G(z7381)}  A
# [2] {F(z7382)}  A
#
# [1] {G(z7384)}  A
# [2] {F(z7385)}  A
#
# [1] {-G(z7387), -F(z7387)}  A
#
# [1] {-G(z7389), -F(z7389)}  A
#
# [1] {-G(z7391), -F(z7391)}  A
#
# [1] {G(z7393)}  A
# [2] {F(z7394)}  A
#
# [1] {-G(z7396), -F(z7396)}  A
#
# [1] {-G(z7398), -F(z7398)}  A
#
# [1] {G(z7400)}  A
# [2] {F(z7401)}  A
#
# [1] {G(z7403)}  A
# [2] {F(z7404)}  A
#
# [1] {G(z7406)}  A
# [2] {F(z7407)}  A
#
# [1] {-G(z7409), -F(z7409)}  A
#
# [1] {-G(z7411), -F(z7411)}  A
#
# [1] {-G(z7413), -F(z7413)}  A
#
# [1] {G(z7415)}  A
# [2] {F(z7416)}  A
#
# [1] {G(z7418)}  A
# [2] {F(z7419)}  A
#
# [1] {G(z7421)}  A
# [2] {F(z7422)}  A
#
# [1] {-G(z7424), -F(z7424)}  A

# %%
tautologyCounts_df = pd.DataFrame()
tautologyCounts_df["tautologyCounts"] = pd.DataFrame(numTautologies)
tautologyCounts_df = tautologyCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
tautologyCounts_df["Correct"] = output_dataset['Correct']
tautologyCounts_df
# Out:
#        tautologyCounts  Correct
# 80000            False     True
# 80001            False     True
# 80002            False     True
# 80003            False    False
# 80004            False     True
# ...                ...      ...
# 80995            False     True
# 80996            False     True
# 80997            False    False
# 80998            False     True
# 80999            False    False
#
# [1000 rows x 2 columns]

# %%
tautologyCounts = tautologyCounts_df.groupby(['Correct', 'tautologyCounts']).size()
tautologyCounts
# Out:
# Correct  tautologyCounts
# False    False              245
#          True                64
# True     False              632
#          True                59
# dtype: int64

# %%
dfp = tautologyCounts_df.pivot_table(index='tautologyCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()

# %%
17/142
# Out:
# 0.11971830985915492

# %%
106/735
# Out:
# 0.14421768707482993

# %%
contradictionCounts_df = pd.DataFrame()
contradictionCounts_df["contradictionCounts"] = pd.DataFrame(numContradictions)
contradictionCounts_df = contradictionCounts_df.set_index(output_dataset.index) # to avoid NaNs (due to different indices)
contradictionCounts_df["Correct"] = output_dataset['Correct']
contradictionCounts_df
# Out:
#        contradictionCounts  Correct
# 80000                False     True
# 80001                False     True
# 80002                False     True
# 80003                False    False
# 80004                False     True
# ...                    ...      ...
# 80995                False     True
# 80996                False     True
# 80997                False    False
# 80998                False     True
# 80999                False    False
#
# [1000 rows x 2 columns]

# %%
contradictionCounts = contradictionCounts_df.groupby(['Correct', 'contradictionCounts']).size()
contradictionCounts
# Out:
# Correct  contradictionCounts
# False    False                  302
#          True                     7
# True     False                  580
#          True                   111
# dtype: int64

# %%
dfp = contradictionCounts_df.pivot_table(index='contradictionCounts', columns='Correct', values='Correct', aggfunc='size')
dfp.plot(kind='bar', figsize=(5, 3), rot=0)
plt.show()
